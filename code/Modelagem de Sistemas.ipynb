# %%
# !pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-1.3.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.5 MB)
#      |████████████████████████████████| 11.5 MB 131 kB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.17.3; platform_machine != "aarch64" and platform_machine != "arm64" and python_version < "3.10" in /home/erick/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages (from pandas) (1.19.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/erick/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages (from pandas) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /home/erick/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages (from pandas) (2020.1)
# Requirement already satisfied: six>=1.5 in /home/erick/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)
# Installing collected packages: pandas
# Successfully installed pandas-1.3.4
# WARNING: You are using pip version 20.2.3; however, version 21.3.1 is available.
# You should consider upgrading via the '/home/erick/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/bin/python3 -m pip install --upgrade pip' command.

# %%
import numpy as np
import pandas as pd
# %display typeset

# %% [markdown]
# Calculando dX/dt:

# %%
var('X mu D t')
X = function('X')(t)
dxdt = diff(X,t) == mu*X-D*X
dxdt
# Out:
# diff(X(t), t) == -D*X(t) + mu*X(t)

# %% [markdown]
# Calculando dS/dt:

# %%
var('S mu D Sf X Y t')
S = function('S')(t)
dsdt = diff(S,t) == D*Sf - D*S -(mu*X/Y)
dsdt
# Out:
# diff(S(t), t) == D*Sf - D*S(t) - X*mu/Y

# %% [markdown]
# Desenvolvendo a matriz jacobiana:

# %%
var('S X mu D Y Sf x s')
J = jacobian([mu*x-D*x, D*Sf - D*s -(mu*x/Y)],[x,s])
J
# Out:
# [-D + mu       0]
# [  -mu/Y      -D]

# %% [markdown]
# Calculando o traço (p):

# %%
J.trace()
# Out:
# -2*D + mu

# %% [markdown]
# Calculando o determinante (q):

# %%
J.det()
# Out:
# (D - mu)*D

# %% [markdown]
# Autovetores:

# %%
J.eigenvectors_right()
# Out:
# [(-D + mu, [(1, -1/Y)], 1), (-D, [(0, 1)], 1)]

# %% [markdown]
# Autovalores:

# %%
J.eigenvalues()
# Out:
# [-D + mu, -D]

# %% [markdown]
# $\lambda_1$: -D
#
# $\lambda_2$: -D+mu

# %% [markdown]
# Os autovalores são reais e distintos, já que mu > 0 (mu é taxa de crescimento específica; 1/Tempo):

# %% [markdown]
# Se mu>D, os sinais dos autovalores são opostos ($\lambda_1$<0<$\lambda_2$): Equilíbrio instável em ponto de sela
#
# Se mu<D, os sinais dos autovalores são iguais, nesse caso negativos, já que D é taxa de diluição e portanto não pode ser negativo ($\lambda_1$<$\lambda_2$<0): Equilíbrio pontual estável
#
# Se mu=D, um dos autovalores será 0. Nesse caso o modelo ficará constante, como pode ser visto mais adiante no notebook.
#
# Note que mu-D será sempre maior que -D, logo mu-D será o autovalor dominante $(\lambda_d)$

# %% [markdown]
# Polinômio característico:

# %%
J.characteristic_polynomial()
# Out:
# x^2 + (2*D - mu)*x + D^2 - D*mu

# %%
J.characteristic_polynomial().roots()
# Out:
# [(-D + mu, 1), (-D, 1)]

# %%
J.jordan_form()
# Out:
# [-D + mu|      0]
# [-------+-------]
# [      0|     -D]

# %%
p = J.trace
print(p)

q = J.det
print(q)
# Out:
# <built-in method trace of sage.matrix.matrix_symbolic_dense.Matrix_symbolic_dense object at 0x7f8320ea62e0>
# <built-in method det of sage.matrix.matrix_symbolic_dense.Matrix_symbolic_dense object at 0x7f8320ea62e0>

# %% [markdown]
# p = -2D+mu
#
# q = D^2 - muD

# %% [markdown]
# Δ=p^2-4*q

# %% [markdown]
# p^2 = (mu-2D)^2 = mu^2 -4muD +4D^2
#
# 4q = 4(D^2 - muD) = 4D^2 - 4muD
#
# Δ = mu^2 -4muD +4D^2 - (4D^2 - 4muD) = mu^2

# %% [markdown]
# Calculando o equilíbrio pontual do sistema:

# %%
var('S X mu D Y Sf x s')
xdot(x,s) = mu*x-D*x
sdot(x,s) = D*Sf - D*s -(mu*x/Y)
solve([xdot, sdot], [x,s])
# Out:
# [[x == 0, s == Sf]]

# %%
dxdt = mu*X-D*X
dsdt = D*Sf - D*S -(mu*X/Y)

solve([dxdt,dsdt], [X,S])
# Out:
# [[X == 0, S == Sf]]

# %% [markdown]
# *-----------------------------------------------------------------------------------------------------*

# %%
var('mu D')
f(x) = mu*x - D*x
raízes = solve(f,x)
show("Raízes=",raízes)
F=plot(f(mu=2, D=1),(x,-2,2))
P=points([(0,0)], pointsize=30, color='red')
F+P
# Out:
# 'Raízes=' [x == 0]
# Graphics object consisting of 2 graphics primitives

# %%
@interact
def linear(mu=(-2,2,1),D=(-1,1,1)):
    P = plot(f(mu=mu, D=D), (x,-1.5,1.5))
    raízes = solve(f,x)
    show("Raízes=",raízes)
    P2=points([(0,0)], pointsize=30, color='red')
    show(P+P2)
# Out:
# Interactive function <function linear at 0x7f831833d310> with 2 widgets
#   mu: IntSlider(value=0, description='mu', max=2, min=-2)
#   D: IntSlider(value=0, description='D', max=1, min=-1)

# %%
var('x s mu D Sf X S mumax Ks')

mu==mumax*s/(Ks + s)

X = function('X')(t)
S = function('S')(t)
de1 = diff(X,t) == mu*X - D*X
de2 = diff(S,t) == D*Sf - D*S -(mu*X/Y)
sol = desolve_system([de1,de2],[X,S],ics=[0,500,0], ivar=t)
show(sol)
# Out:
# [X(t) == 500*e^(-(D - mu)*t),
#  S(t) == Sf - (Sf*Y - 500)*e^(-D*t)/Y - 500*e^(-(D - mu)*t)/Y]

# %% [markdown]
# Legenda:
#
#
# Azul==X (Concentração celular)
#
# Verde==S (Concentração de substrato)

# %%
# Atribuindo  valores para as taxas de conversão:
solX, solS = sol[0].rhs(), sol[1].rhs()
plot((solX(mu=0.5, D=1, Y=0.8, Sf=20),solS(mu=0.5, D=1, Y=0.8, Sf=20)),(t,0,30))
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
# Atribuindo  valores para as taxas de conversão:
solX, solS = sol[0].rhs(), sol[1].rhs()
plot((solX(mu=1, D=1, Y=0.8, Sf=20),solS(mu=1, D=1, Y=0.8, Sf=20)),(t,0,30))
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
# Atribuindo  valores para as taxas de conversão:
solX, solS = sol[0].rhs(), sol[1].rhs()
plot((solX(mu=0.5, D=1, Y=0.3, Sf=20),solS(mu=0.5, D=1, Y=0.3, Sf=20)),(t,0,30))
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
# Atribuindo  valores para as taxas de conversão:
solX, solS = sol[0].rhs(), sol[1].rhs()
plot((solX(mu=0.5, D=0.381, Y=0.3, Sf=1),solS(mu=0.5, D=0.381, Y=0.3, Sf=1)),(t,0,30))
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
# Atribuindo  valores para as taxas de conversão:
solX, solS = sol[0].rhs(), sol[1].rhs()
plot((solX(mu=0.5, D=0.1, Y=0.3, Sf=1),solS(mu=0.5, D=0.1, Y=0.3, Sf=1)),(t,0,30))
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
# Atribuindo  valores para as taxas de conversão:
solX, solS = sol[0].rhs(), sol[1].rhs()
plot((solX(mu=0.5, D=0.1, Y=0.3, Sf=10),solS(mu=0.5, D=0.1, Y=0.3, Sf=10)),(t,0,30))
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
# Atribuindo  valores para as taxas de conversão:
solX, solS = sol[0].rhs(), sol[1].rhs()
plot((solX(mu=0.5, D=1, Y=0.3, Sf=10),solS(mu=0.5, D=1, Y=0.3, Sf=10)),(t,0,30))
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
# Atribuindo  valores para as taxas de conversão:
solX, solS = sol[0].rhs(), sol[1].rhs()
plot((solX(mu=1, D=1, Y=0.3, Sf=10),solS(mu=1, D=1, Y=0.3, Sf=10)),(t,0,30))
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
# Atribuindo  valores para as taxas de conversão:
solX, solS = sol[0].rhs(), sol[1].rhs()
plot((solX(mu=0.4, D=0.381, Y=0.8, Sf=20),solS(mu=0.4, D=0.381, Y=0.8, Sf=20)),(t,0,30))
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
# Atribuindo  valores para as taxas de conversão:
solX, solS = sol[0].rhs(), sol[1].rhs()
plot((solX(mu=0.4, D=0.381, Y=0.3, Sf=20),solS(mu=0.4, D=0.381, Y=0.3, Sf=20)),(t,0,30))
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
# Atribuindo  valores para as taxas de conversão:
solX, solS = sol[0].rhs(), sol[1].rhs()
plot((solX(mu=1.45, D=1, Y=0.8, Sf=20),solS(mu=1.45, D=1, Y=0.8, Sf=20)),(t,0,30))
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
# Atribuindo  valores para as taxas de conversão:
solX, solS = sol[0].rhs(), sol[1].rhs()
plot((solX(mu=0.398, D=0.381, Y=0.4, Sf=1),solS(mu=0.398, D=0.381, Y=0.4, Sf=1)),(t,0,30))
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
var('mu D Sf X Y')
f(s) = D*Sf - D*s -(mu*X/Y)
raízes = solve(f,s)
show("Raízes=",raízes)
F=plot(s(mu=2, D=1, Sf=20, X=0, Y=0.8),(s,-2,2))
P=points([(0,0)], pointsize=30, color='red')
F+P
# Out:
# 'Raízes=' [s == (D*Sf*Y - X*mu)/(D*Y)]
# Graphics object consisting of 2 graphics primitives

# %%
var('mu D Sf Y')
f(s) = D*Sf - D*s -(mu*x/Y)
raízes = solve(f,s)
show("Raízes=",raízes)
F=plot(s(mu=2, D=1, Sf=20, X=0, Y=0.8),(s,-2,2))
P=points([(0,0)], pointsize=30, color='red')
F+P
# Out:
# 'Raízes=' [s == (D*Sf*Y - mu*x)/(D*Y)]
# Graphics object consisting of 2 graphics primitives

# %%
def fun(t,y):
    x,s = y
    return [Y*(Sf-(Ks*D)/(mumax-D)),
            Ks*D/(mumax-D)]

# %%
'''T = ode_solver()
T.algorithm='rk8pd'
T.function = fun
y0=[1,0]
T.ode_solve(t_span=[0,10],y_0=y0, num_points=100)'''

#Verificar como resolver esse problema depois
# Out:
# "T = ode_solver()\nT.algorithm='rk8pd'\nT.function = fun\ny0=[1,0]\nT.ode_solve(t_span=[0,10],y_0=y0, num_points=100)"

# %%
var('t x s mu D Sf X Y mumax Ks')

X = function('X')(t)
S = function('S')(t)
de1 = diff(X,t) == mu*X - D*X
de2 = diff(S,t) == D*Sf - D*S -(mu*X/Y)
sol = desolve_system([de1,de2],[X,S],ics=[0,500,0], ivar=t)
show(sol)
# Out:
# [X(t) == 500*e^(-(D - mu)*t),
#  S(t) == Sf - (Sf*Y - 500)*e^(-D*t)/Y - 500*e^(-(D - mu)*t)/Y]

# %%
# Atribuindo  valores para as taxas de conversão:
solX, solS = sol[0].rhs(), sol[1].rhs()
plot((solX(mu=1.6, Ks= 1, D=1, Y=0.8, Sf=20),solS(mu=1.6, Ks= 1, D=1, Y=0.8, Sf=20)),(t,0,30))
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
# Atribuindo  valores para as taxas de conversão:
solX, solS = sol[0].rhs(), sol[1].rhs()
plot((solX(mu=1, D=1, Y=1, Sf=1),solS(mu=1, D=1, Y=1, Sf=1)),(t,0,30))
# Out:
# Graphics object consisting of 2 graphics primitives

# %% [markdown]
# *-----------------------------------------------------------------------------------------------------*

# %% [markdown]
# As equações de soluções de estado estacionário são as seguintes:

# %% [markdown]
# S = KsD/(mumax-D)

# %% [markdown]
# X = Y(Sf- KsD/(mumax-D))

# %% [markdown]
# mu = mumax.S/(Ks+S)

# %%
mumax = 1.6
Ks = 1
Y = 0.8
Sf = 20
D = 1

# %%
S = Ks*D/(mumax-D)
print(S)
# Out:
# 1.66666666666667

# %%
X = Y*(Sf- Ks*D/(mumax-D))
print(X)
# Out:
# 14.6666666666667

# %%
mu = mumax*S/(Ks+S)
print(mu)
# Out:
# 1.00000000000000

# %%
# Atribuindo  valores para as taxas de conversão:
solX, solS = sol[0].rhs(), sol[1].rhs()
plot((solX(mu=1, D=1, Y=0.8, Sf=20),solS(mu=1, D=1, Y=0.8, Sf=20)),(t,0,30))
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
var('x s mu D Sf X S mumax Ks')

mu=mumax*S/(Ks + S)

X = function('X')(t)
S = function('S')(t)
de1 = diff(X,t) == mu*X - D*X
de2 = diff(S,t) == D*Sf - D*S -(mu*X/Y)
sol = desolve_system([de1,de2],[X,S],ics=[0,500,0], ivar=t)
show(sol)
# Out:
# [X(t) == 500*e^(-(D*Ks + D*S - S*mumax)*t/(Ks + S)),
#  S(t) == -(Sf - 625)*e^(-D*t) + Sf - 625*e^(-(D*Ks + D*S - S*mumax)*t/(Ks + S))]

# %%
# Atribuindo  valores para as taxas de conversão:
solX, solS = sol[0].rhs(), sol[1].rhs()
plot((solX(mumax=1.6, Ks= 1, D=1, Y=0.8, Sf=20),solS(mumax=1.6, Ks= 1, D=1, Y=0.8, Sf=20)),(t,0,30))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/ext/fast_callable.pyx in sage.ext.fast_callable.ExpressionTreeBuilder.var (build/cythonized/sage/ext/fast_callable.c:6740)()
#     687         try:
# --> 688             ind = self._vars.index(var_name)
#     689         except ValueError:
#
# ValueError: 'mu' is not in list
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-9613d4fe57d2> in <module>
#       1 # Atribuindo  valores para as taxas de conversão:
#       2 solX, solS = sol[Integer(0)].rhs(), sol[Integer(1)].rhs()
# ----> 3 plot((solX(mumax=RealNumber('1.6'), Ks= Integer(1), D=Integer(1), Y=RealNumber('0.8'), Sf=Integer(20)),solS(mumax=RealNumber('1.6'), Ks= Integer(1), D=Integer(1), Y=RealNumber('0.8'), Sf=Integer(20))),(t,Integer(0),Integer(30)))
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/misc/decorators.py in wrapper(*args, **kwds)
#     490                 options['__original_opts'] = kwds
#     491             options.update(kwds)
# --> 492             return func(*args, **options)
#     493
#     494         #Add the options specified by @options to the signature of the wrapped
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/plot/plot.py in plot(funcs, *args, **kwds)
#    1978         # if there is one extra arg, then it had better be a tuple
#    1979         elif n == 1:
# -> 1980             G = _plot(funcs, *args, **kwds)
#    1981         elif n == 2:
#    1982         # if there are two extra args, then pull them out and pass them as a tuple
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/plot/plot.py in _plot(funcs, xrange, parametric, polar, fill, label, randomize, **options)
#    2094     orig_funcs = funcs # keep the original functions (for use in legend labels)
#    2095     excluded_points = []
# -> 2096     funcs, ranges = setup_for_eval_on_grid(funcs, [xrange], options['plot_points'])
#    2097     xmin, xmax, delta = ranges[0]
#    2098     xrange=ranges[0][:2]
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/plot/misc.py in setup_for_eval_on_grid(funcs, ranges, plot_points, return_vars)
#     149                 vars)
#     150     else:
# --> 151         return (fast_float(funcs, *vars, **options),
#     152                 [tuple(_range + [range_step])
#     153                  for _range, range_step in zip(ranges, range_steps)])
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/ext/fast_eval.pyx in sage.ext.fast_eval.fast_float (build/cythonized/sage/ext/fast_eval.c:11000)()
#    1374
#    1375     if isinstance(f, (tuple, list)):
# -> 1376         return tuple([fast_float(x, *vars, expect_one_var=expect_one_var) for x in f])
#    1377
#    1378     cdef int i
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/ext/fast_eval.pyx in sage.ext.fast_eval.fast_float (build/cythonized/sage/ext/fast_eval.c:11250)()
#    1389             return f._fast_float_(*vars)
#    1390         else:
# -> 1391             return fast_callable(f, vars=vars, domain=float,
#    1392                                  expect_one_var=expect_one_var)
#    1393     except AttributeError:
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/ext/fast_callable.pyx in sage.ext.fast_callable.fast_callable (build/cythonized/sage/ext/fast_callable.c:4708)()
#     455
#     456         etb = ExpressionTreeBuilder(vars=vars, domain=domain)
# --> 457         et = x._fast_callable_(etb)
#     458
#     459     if isinstance(domain, RealField_class):
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/symbolic/expression.pyx in sage.symbolic.expression.Expression._fast_callable_ (build/cythonized/sage/symbolic/expression.cpp:64777)()
#   12056         """
#   12057         from sage.symbolic.expression_conversions import fast_callable
# > 12058         return fast_callable(self, etb)
#   12059
#   12060     def show(self):
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/symbolic/expression_conversions.py in fast_callable(ex, etb)
#    1927
#    1928     """
# -> 1929     return FastCallableConverter(ex, etb)()
#    1930
#    1931 class RingConverter(Converter):
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/symbolic/expression_conversions.py in __call__(self, ex)
#     215             if getattr(self, 'use_fake_div', False) and (operator is _operator.mul or operator is mul_vararg):
#     216                 div = self.get_fake_div(ex)
# --> 217                 return self.arithmetic(div, div.operator())
#     218             return self.arithmetic(ex, operator)
#     219         elif operator in relation_operators:
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/symbolic/expression_conversions.py in arithmetic(self, ex, operator)
#    1855         elif operator == mul_vararg:
#    1856             operator = _operator.mul
# -> 1857         return reduce(lambda x,y: self.etb.call(operator, x,y), operands)
#    1858
#    1859     def symbol(self, ex):
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/symbolic/expression_conversions.py in <lambda>(x, y)
#    1855         elif operator == mul_vararg:
#    1856             operator = _operator.mul
# -> 1857         return reduce(lambda x,y: self.etb.call(operator, x,y), operands)
#    1858
#    1859     def symbol(self, ex):
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/ext/fast_callable.pyx in sage.ext.fast_callable.ExpressionTreeBuilder.call (build/cythonized/sage/ext/fast_callable.c:7205)()
#     742             return self(base)**exponent
#     743         else:
# --> 744             return ExpressionCall(self, fn, [self(a) for a in args])
#     745
#     746     def choice(self, cond, iftrue, iffalse):
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/ext/fast_callable.pyx in sage.ext.fast_callable.ExpressionTreeBuilder.__call__ (build/cythonized/sage/ext/fast_callable.c:6321)()
#     616             return self.constant(x)
#     617
# --> 618         return fc(self)
#     619
#     620     def _clean_var(self, v):
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/symbolic/expression.pyx in sage.symbolic.expression.Expression._fast_callable_ (build/cythonized/sage/symbolic/expression.cpp:64777)()
#   12056         """
#   12057         from sage.symbolic.expression_conversions import fast_callable
# > 12058         return fast_callable(self, etb)
#   12059
#   12060     def show(self):
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/symbolic/expression_conversions.py in fast_callable(ex, etb)
#    1927
#    1928     """
# -> 1929     return FastCallableConverter(ex, etb)()
#    1930
#    1931 class RingConverter(Converter):
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/symbolic/expression_conversions.py in __call__(self, ex)
#     224             return self.tuple(ex)
#     225         else:
# --> 226             return self.composition(ex, operator)
#     227
#     228     def get_fake_div(self, ex):
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/symbolic/expression_conversions.py in composition(self, ex, function)
#    1893             {arctan2}(v_0, v_1)
#    1894         """
# -> 1895         return self.etb.call(function, *ex.operands())
#    1896
#    1897     def tuple(self, ex):
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/ext/fast_callable.pyx in sage.ext.fast_callable.ExpressionTreeBuilder.call (build/cythonized/sage/ext/fast_callable.c:7205)()
#     742             return self(base)**exponent
#     743         else:
# --> 744             return ExpressionCall(self, fn, [self(a) for a in args])
#     745
#     746     def choice(self, cond, iftrue, iffalse):
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/ext/fast_callable.pyx in sage.ext.fast_callable.ExpressionTreeBuilder.__call__ (build/cythonized/sage/ext/fast_callable.c:6321)()
#     616             return self.constant(x)
#     617
# --> 618         return fc(self)
#     619
#     620     def _clean_var(self, v):
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/symbolic/expression.pyx in sage.symbolic.expression.Expression._fast_callable_ (build/cythonized/sage/symbolic/expression.cpp:64777)()
#   12056         """
#   12057         from sage.symbolic.expression_conversions import fast_callable
# > 12058         return fast_callable(self, etb)
#   12059
#   12060     def show(self):
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/symbolic/expression_conversions.py in fast_callable(ex, etb)
#    1927
#    1928     """
# -> 1929     return FastCallableConverter(ex, etb)()
#    1930
#    1931 class RingConverter(Converter):
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/symbolic/expression_conversions.py in __call__(self, ex)
#     215             if getattr(self, 'use_fake_div', False) and (operator is _operator.mul or operator is mul_vararg):
#     216                 div = self.get_fake_div(ex)
# --> 217                 return self.arithmetic(div, div.operator())
#     218             return self.arithmetic(ex, operator)
#     219         elif operator in relation_operators:
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/symbolic/expression_conversions.py in arithmetic(self, ex, operator)
#    1855         elif operator == mul_vararg:
#    1856             operator = _operator.mul
# -> 1857         return reduce(lambda x,y: self.etb.call(operator, x,y), operands)
#    1858
#    1859     def symbol(self, ex):
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/symbolic/expression_conversions.py in <lambda>(x, y)
#    1855         elif operator == mul_vararg:
#    1856             operator = _operator.mul
# -> 1857         return reduce(lambda x,y: self.etb.call(operator, x,y), operands)
#    1858
#    1859     def symbol(self, ex):
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/ext/fast_callable.pyx in sage.ext.fast_callable.ExpressionTreeBuilder.call (build/cythonized/sage/ext/fast_callable.c:7205)()
#     742             return self(base)**exponent
#     743         else:
# --> 744             return ExpressionCall(self, fn, [self(a) for a in args])
#     745
#     746     def choice(self, cond, iftrue, iffalse):
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/ext/fast_callable.pyx in sage.ext.fast_callable.ExpressionTreeBuilder.__call__ (build/cythonized/sage/ext/fast_callable.c:6321)()
#     616             return self.constant(x)
#     617
# --> 618         return fc(self)
#     619
#     620     def _clean_var(self, v):
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/symbolic/expression.pyx in sage.symbolic.expression.Expression._fast_callable_ (build/cythonized/sage/symbolic/expression.cpp:64777)()
#   12056         """
#   12057         from sage.symbolic.expression_conversions import fast_callable
# > 12058         return fast_callable(self, etb)
#   12059
#   12060     def show(self):
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/symbolic/expression_conversions.py in fast_callable(ex, etb)
#    1927
#    1928     """
# -> 1929     return FastCallableConverter(ex, etb)()
#    1930
#    1931 class RingConverter(Converter):
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/symbolic/expression_conversions.py in __call__(self, ex)
#     216                 div = self.get_fake_div(ex)
#     217                 return self.arithmetic(div, div.operator())
# --> 218             return self.arithmetic(ex, operator)
#     219         elif operator in relation_operators:
#     220             return self.relation(ex, operator)
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/symbolic/expression_conversions.py in arithmetic(self, ex, operator)
#    1855         elif operator == mul_vararg:
#    1856             operator = _operator.mul
# -> 1857         return reduce(lambda x,y: self.etb.call(operator, x,y), operands)
#    1858
#    1859     def symbol(self, ex):
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/symbolic/expression_conversions.py in <lambda>(x, y)
#    1855         elif operator == mul_vararg:
#    1856             operator = _operator.mul
# -> 1857         return reduce(lambda x,y: self.etb.call(operator, x,y), operands)
#    1858
#    1859     def symbol(self, ex):
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/ext/fast_callable.pyx in sage.ext.fast_callable.ExpressionTreeBuilder.call (build/cythonized/sage/ext/fast_callable.c:7205)()
#     742             return self(base)**exponent
#     743         else:
# --> 744             return ExpressionCall(self, fn, [self(a) for a in args])
#     745
#     746     def choice(self, cond, iftrue, iffalse):
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/ext/fast_callable.pyx in sage.ext.fast_callable.ExpressionTreeBuilder.__call__ (build/cythonized/sage/ext/fast_callable.c:6321)()
#     616             return self.constant(x)
#     617
# --> 618         return fc(self)
#     619
#     620     def _clean_var(self, v):
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/symbolic/expression.pyx in sage.symbolic.expression.Expression._fast_callable_ (build/cythonized/sage/symbolic/expression.cpp:64777)()
#   12056         """
#   12057         from sage.symbolic.expression_conversions import fast_callable
# > 12058         return fast_callable(self, etb)
#   12059
#   12060     def show(self):
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/symbolic/expression_conversions.py in fast_callable(ex, etb)
#    1927
#    1928     """
# -> 1929     return FastCallableConverter(ex, etb)()
#    1930
#    1931 class RingConverter(Converter):
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/symbolic/expression_conversions.py in __call__(self, ex)
#     210         operator = ex.operator()
#     211         if operator is None:
# --> 212             return self.symbol(ex)
#     213
#     214         if operator in arithmetic_operators:
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/symbolic/expression_conversions.py in symbol(self, ex)
#    1876             ValueError: Variable 'z' not found
#    1877         """
# -> 1878         return self.etb.var(SR(ex))
#    1879
#    1880     def composition(self, ex, function):
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/ext/fast_callable.pyx in sage.ext.fast_callable.ExpressionTreeBuilder.var (build/cythonized/sage/ext/fast_callable.c:6792)()
#     688             ind = self._vars.index(var_name)
#     689         except ValueError:
# --> 690             raise ValueError("Variable '%s' not found" % var_name)
#     691         return ExpressionVariable(self, ind)
#     692
#
# ValueError: Variable 'mu' not found

# %%
# Atribuindo  valores para as taxas de conversão:
solX, solS = sol[0].rhs(), sol[1].rhs()
plot((solX(mumax=1.6, Ks= 1, D=1, Y=0.8, Sf=20, S=1.66666666666667),solS(mumax=1.6, Ks= 1, D=1, Y=0.8, Sf=20, S=1.66666666666667)),(t,0,30))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/ext/fast_callable.pyx in sage.ext.fast_callable.ExpressionTreeBuilder.var (build/cythonized/sage/ext/fast_callable.c:6740)()
#     687         try:
# --> 688             ind = self._vars.index(var_name)
#     689         except ValueError:
#
# ValueError: 'mu' is not in list
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-a6b9e65d7efe> in <module>
#       1 # Atribuindo  valores para as taxas de conversão:
#       2 solX, solS = sol[Integer(0)].rhs(), sol[Integer(1)].rhs()
# ----> 3 plot((solX(mumax=RealNumber('1.6'), Ks= Integer(1), D=Integer(1), Y=RealNumber('0.8'), Sf=Integer(20), S=RealNumber('1.66666666666667')),solS(mumax=RealNumber('1.6'), Ks= Integer(1), D=Integer(1), Y=RealNumber('0.8'), Sf=Integer(20), S=RealNumber('1.66666666666667'))),(t,Integer(0),Integer(30)))
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/misc/decorators.py in wrapper(*args, **kwds)
#     490                 options['__original_opts'] = kwds
#     491             options.update(kwds)
# --> 492             return func(*args, **options)
#     493
#     494         #Add the options specified by @options to the signature of the wrapped
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/plot/plot.py in plot(funcs, *args, **kwds)
#    1978         # if there is one extra arg, then it had better be a tuple
#    1979         elif n == 1:
# -> 1980             G = _plot(funcs, *args, **kwds)
#    1981         elif n == 2:
#    1982         # if there are two extra args, then pull them out and pass them as a tuple
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/plot/plot.py in _plot(funcs, xrange, parametric, polar, fill, label, randomize, **options)
#    2094     orig_funcs = funcs # keep the original functions (for use in legend labels)
#    2095     excluded_points = []
# -> 2096     funcs, ranges = setup_for_eval_on_grid(funcs, [xrange], options['plot_points'])
#    2097     xmin, xmax, delta = ranges[0]
#    2098     xrange=ranges[0][:2]
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/plot/misc.py in setup_for_eval_on_grid(funcs, ranges, plot_points, return_vars)
#     149                 vars)
#     150     else:
# --> 151         return (fast_float(funcs, *vars, **options),
#     152                 [tuple(_range + [range_step])
#     153                  for _range, range_step in zip(ranges, range_steps)])
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/ext/fast_eval.pyx in sage.ext.fast_eval.fast_float (build/cythonized/sage/ext/fast_eval.c:11000)()
#    1374
#    1375     if isinstance(f, (tuple, list)):
# -> 1376         return tuple([fast_float(x, *vars, expect_one_var=expect_one_var) for x in f])
#    1377
#    1378     cdef int i
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/ext/fast_eval.pyx in sage.ext.fast_eval.fast_float (build/cythonized/sage/ext/fast_eval.c:11250)()
#    1389             return f._fast_float_(*vars)
#    1390         else:
# -> 1391             return fast_callable(f, vars=vars, domain=float,
#    1392                                  expect_one_var=expect_one_var)
#    1393     except AttributeError:
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/ext/fast_callable.pyx in sage.ext.fast_callable.fast_callable (build/cythonized/sage/ext/fast_callable.c:4708)()
#     455
#     456         etb = ExpressionTreeBuilder(vars=vars, domain=domain)
# --> 457         et = x._fast_callable_(etb)
#     458
#     459     if isinstance(domain, RealField_class):
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/symbolic/expression.pyx in sage.symbolic.expression.Expression._fast_callable_ (build/cythonized/sage/symbolic/expression.cpp:64777)()
#   12056         """
#   12057         from sage.symbolic.expression_conversions import fast_callable
# > 12058         return fast_callable(self, etb)
#   12059
#   12060     def show(self):
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/symbolic/expression_conversions.py in fast_callable(ex, etb)
#    1927
#    1928     """
# -> 1929     return FastCallableConverter(ex, etb)()
#    1930
#    1931 class RingConverter(Converter):
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/symbolic/expression_conversions.py in __call__(self, ex)
#     215             if getattr(self, 'use_fake_div', False) and (operator is _operator.mul or operator is mul_vararg):
#     216                 div = self.get_fake_div(ex)
# --> 217                 return self.arithmetic(div, div.operator())
#     218             return self.arithmetic(ex, operator)
#     219         elif operator in relation_operators:
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/symbolic/expression_conversions.py in arithmetic(self, ex, operator)
#    1855         elif operator == mul_vararg:
#    1856             operator = _operator.mul
# -> 1857         return reduce(lambda x,y: self.etb.call(operator, x,y), operands)
#    1858
#    1859     def symbol(self, ex):
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/symbolic/expression_conversions.py in <lambda>(x, y)
#    1855         elif operator == mul_vararg:
#    1856             operator = _operator.mul
# -> 1857         return reduce(lambda x,y: self.etb.call(operator, x,y), operands)
#    1858
#    1859     def symbol(self, ex):
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/ext/fast_callable.pyx in sage.ext.fast_callable.ExpressionTreeBuilder.call (build/cythonized/sage/ext/fast_callable.c:7205)()
#     742             return self(base)**exponent
#     743         else:
# --> 744             return ExpressionCall(self, fn, [self(a) for a in args])
#     745
#     746     def choice(self, cond, iftrue, iffalse):
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/ext/fast_callable.pyx in sage.ext.fast_callable.ExpressionTreeBuilder.__call__ (build/cythonized/sage/ext/fast_callable.c:6321)()
#     616             return self.constant(x)
#     617
# --> 618         return fc(self)
#     619
#     620     def _clean_var(self, v):
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/symbolic/expression.pyx in sage.symbolic.expression.Expression._fast_callable_ (build/cythonized/sage/symbolic/expression.cpp:64777)()
#   12056         """
#   12057         from sage.symbolic.expression_conversions import fast_callable
# > 12058         return fast_callable(self, etb)
#   12059
#   12060     def show(self):
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/symbolic/expression_conversions.py in fast_callable(ex, etb)
#    1927
#    1928     """
# -> 1929     return FastCallableConverter(ex, etb)()
#    1930
#    1931 class RingConverter(Converter):
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/symbolic/expression_conversions.py in __call__(self, ex)
#     224             return self.tuple(ex)
#     225         else:
# --> 226             return self.composition(ex, operator)
#     227
#     228     def get_fake_div(self, ex):
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/symbolic/expression_conversions.py in composition(self, ex, function)
#    1893             {arctan2}(v_0, v_1)
#    1894         """
# -> 1895         return self.etb.call(function, *ex.operands())
#    1896
#    1897     def tuple(self, ex):
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/ext/fast_callable.pyx in sage.ext.fast_callable.ExpressionTreeBuilder.call (build/cythonized/sage/ext/fast_callable.c:7205)()
#     742             return self(base)**exponent
#     743         else:
# --> 744             return ExpressionCall(self, fn, [self(a) for a in args])
#     745
#     746     def choice(self, cond, iftrue, iffalse):
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/ext/fast_callable.pyx in sage.ext.fast_callable.ExpressionTreeBuilder.__call__ (build/cythonized/sage/ext/fast_callable.c:6321)()
#     616             return self.constant(x)
#     617
# --> 618         return fc(self)
#     619
#     620     def _clean_var(self, v):
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/symbolic/expression.pyx in sage.symbolic.expression.Expression._fast_callable_ (build/cythonized/sage/symbolic/expression.cpp:64777)()
#   12056         """
#   12057         from sage.symbolic.expression_conversions import fast_callable
# > 12058         return fast_callable(self, etb)
#   12059
#   12060     def show(self):
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/symbolic/expression_conversions.py in fast_callable(ex, etb)
#    1927
#    1928     """
# -> 1929     return FastCallableConverter(ex, etb)()
#    1930
#    1931 class RingConverter(Converter):
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/symbolic/expression_conversions.py in __call__(self, ex)
#     215             if getattr(self, 'use_fake_div', False) and (operator is _operator.mul or operator is mul_vararg):
#     216                 div = self.get_fake_div(ex)
# --> 217                 return self.arithmetic(div, div.operator())
#     218             return self.arithmetic(ex, operator)
#     219         elif operator in relation_operators:
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/symbolic/expression_conversions.py in arithmetic(self, ex, operator)
#    1855         elif operator == mul_vararg:
#    1856             operator = _operator.mul
# -> 1857         return reduce(lambda x,y: self.etb.call(operator, x,y), operands)
#    1858
#    1859     def symbol(self, ex):
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/symbolic/expression_conversions.py in <lambda>(x, y)
#    1855         elif operator == mul_vararg:
#    1856             operator = _operator.mul
# -> 1857         return reduce(lambda x,y: self.etb.call(operator, x,y), operands)
#    1858
#    1859     def symbol(self, ex):
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/ext/fast_callable.pyx in sage.ext.fast_callable.ExpressionTreeBuilder.call (build/cythonized/sage/ext/fast_callable.c:7205)()
#     742             return self(base)**exponent
#     743         else:
# --> 744             return ExpressionCall(self, fn, [self(a) for a in args])
#     745
#     746     def choice(self, cond, iftrue, iffalse):
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/ext/fast_callable.pyx in sage.ext.fast_callable.ExpressionTreeBuilder.__call__ (build/cythonized/sage/ext/fast_callable.c:6321)()
#     616             return self.constant(x)
#     617
# --> 618         return fc(self)
#     619
#     620     def _clean_var(self, v):
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/symbolic/expression.pyx in sage.symbolic.expression.Expression._fast_callable_ (build/cythonized/sage/symbolic/expression.cpp:64777)()
#   12056         """
#   12057         from sage.symbolic.expression_conversions import fast_callable
# > 12058         return fast_callable(self, etb)
#   12059
#   12060     def show(self):
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/symbolic/expression_conversions.py in fast_callable(ex, etb)
#    1927
#    1928     """
# -> 1929     return FastCallableConverter(ex, etb)()
#    1930
#    1931 class RingConverter(Converter):
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/symbolic/expression_conversions.py in __call__(self, ex)
#     216                 div = self.get_fake_div(ex)
#     217                 return self.arithmetic(div, div.operator())
# --> 218             return self.arithmetic(ex, operator)
#     219         elif operator in relation_operators:
#     220             return self.relation(ex, operator)
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/symbolic/expression_conversions.py in arithmetic(self, ex, operator)
#    1855         elif operator == mul_vararg:
#    1856             operator = _operator.mul
# -> 1857         return reduce(lambda x,y: self.etb.call(operator, x,y), operands)
#    1858
#    1859     def symbol(self, ex):
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/symbolic/expression_conversions.py in <lambda>(x, y)
#    1855         elif operator == mul_vararg:
#    1856             operator = _operator.mul
# -> 1857         return reduce(lambda x,y: self.etb.call(operator, x,y), operands)
#    1858
#    1859     def symbol(self, ex):
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/ext/fast_callable.pyx in sage.ext.fast_callable.ExpressionTreeBuilder.call (build/cythonized/sage/ext/fast_callable.c:7205)()
#     742             return self(base)**exponent
#     743         else:
# --> 744             return ExpressionCall(self, fn, [self(a) for a in args])
#     745
#     746     def choice(self, cond, iftrue, iffalse):
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/ext/fast_callable.pyx in sage.ext.fast_callable.ExpressionTreeBuilder.__call__ (build/cythonized/sage/ext/fast_callable.c:6321)()
#     616             return self.constant(x)
#     617
# --> 618         return fc(self)
#     619
#     620     def _clean_var(self, v):
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/symbolic/expression.pyx in sage.symbolic.expression.Expression._fast_callable_ (build/cythonized/sage/symbolic/expression.cpp:64777)()
#   12056         """
#   12057         from sage.symbolic.expression_conversions import fast_callable
# > 12058         return fast_callable(self, etb)
#   12059
#   12060     def show(self):
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/symbolic/expression_conversions.py in fast_callable(ex, etb)
#    1927
#    1928     """
# -> 1929     return FastCallableConverter(ex, etb)()
#    1930
#    1931 class RingConverter(Converter):
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/symbolic/expression_conversions.py in __call__(self, ex)
#     210         operator = ex.operator()
#     211         if operator is None:
# --> 212             return self.symbol(ex)
#     213
#     214         if operator in arithmetic_operators:
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/symbolic/expression_conversions.py in symbol(self, ex)
#    1876             ValueError: Variable 'z' not found
#    1877         """
# -> 1878         return self.etb.var(SR(ex))
#    1879
#    1880     def composition(self, ex, function):
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/ext/fast_callable.pyx in sage.ext.fast_callable.ExpressionTreeBuilder.var (build/cythonized/sage/ext/fast_callable.c:6792)()
#     688             ind = self._vars.index(var_name)
#     689         except ValueError:
# --> 690             raise ValueError("Variable '%s' not found" % var_name)
#     691         return ExpressionVariable(self, ind)
#     692
#
# ValueError: Variable 'mu' not found

# %%
mumax=1.6
Ks= 1
D=1
Y=0.8
Sf=20
S=1.66666666666667

plot((Y*(Sf- Ks*D/(mumax-D)), Ks*D/(mumax-D)),(t,0,30))
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
# Atribuindo  valores para as taxas de conversão:
solX, solS = sol[0].rhs(), sol[1].rhs()
plot((solX(mumax=6, Ks= 1, D=4, Y=0.8, Sf=20, S=2),solS(mumax=6, Ks= 1, D=4, Y=0.8, Sf=20, S=2)),(t,0,30))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/ext/fast_callable.pyx in sage.ext.fast_callable.ExpressionTreeBuilder.var (build/cythonized/sage/ext/fast_callable.c:6740)()
#     687         try:
# --> 688             ind = self._vars.index(var_name)
#     689         except ValueError:
#
# ValueError: 'mu' is not in list
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-13dacd99d1cf> in <module>
#       1 # Atribuindo  valores para as taxas de conversão:
#       2 solX, solS = sol[Integer(0)].rhs(), sol[Integer(1)].rhs()
# ----> 3 plot((solX(mumax=Integer(6), Ks= Integer(1), D=Integer(4), Y=RealNumber('0.8'), Sf=Integer(20), S=Integer(2)),solS(mumax=Integer(6), Ks= Integer(1), D=Integer(4), Y=RealNumber('0.8'), Sf=Integer(20), S=Integer(2))),(t,Integer(0),Integer(30)))
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/misc/decorators.py in wrapper(*args, **kwds)
#     490                 options['__original_opts'] = kwds
#     491             options.update(kwds)
# --> 492             return func(*args, **options)
#     493
#     494         #Add the options specified by @options to the signature of the wrapped
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/plot/plot.py in plot(funcs, *args, **kwds)
#    1978         # if there is one extra arg, then it had better be a tuple
#    1979         elif n == 1:
# -> 1980             G = _plot(funcs, *args, **kwds)
#    1981         elif n == 2:
#    1982         # if there are two extra args, then pull them out and pass them as a tuple
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/plot/plot.py in _plot(funcs, xrange, parametric, polar, fill, label, randomize, **options)
#    2094     orig_funcs = funcs # keep the original functions (for use in legend labels)
#    2095     excluded_points = []
# -> 2096     funcs, ranges = setup_for_eval_on_grid(funcs, [xrange], options['plot_points'])
#    2097     xmin, xmax, delta = ranges[0]
#    2098     xrange=ranges[0][:2]
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/plot/misc.py in setup_for_eval_on_grid(funcs, ranges, plot_points, return_vars)
#     149                 vars)
#     150     else:
# --> 151         return (fast_float(funcs, *vars, **options),
#     152                 [tuple(_range + [range_step])
#     153                  for _range, range_step in zip(ranges, range_steps)])
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/ext/fast_eval.pyx in sage.ext.fast_eval.fast_float (build/cythonized/sage/ext/fast_eval.c:11000)()
#    1374
#    1375     if isinstance(f, (tuple, list)):
# -> 1376         return tuple([fast_float(x, *vars, expect_one_var=expect_one_var) for x in f])
#    1377
#    1378     cdef int i
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/ext/fast_eval.pyx in sage.ext.fast_eval.fast_float (build/cythonized/sage/ext/fast_eval.c:11250)()
#    1389             return f._fast_float_(*vars)
#    1390         else:
# -> 1391             return fast_callable(f, vars=vars, domain=float,
#    1392                                  expect_one_var=expect_one_var)
#    1393     except AttributeError:
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/ext/fast_callable.pyx in sage.ext.fast_callable.fast_callable (build/cythonized/sage/ext/fast_callable.c:4708)()
#     455
#     456         etb = ExpressionTreeBuilder(vars=vars, domain=domain)
# --> 457         et = x._fast_callable_(etb)
#     458
#     459     if isinstance(domain, RealField_class):
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/symbolic/expression.pyx in sage.symbolic.expression.Expression._fast_callable_ (build/cythonized/sage/symbolic/expression.cpp:64777)()
#   12056         """
#   12057         from sage.symbolic.expression_conversions import fast_callable
# > 12058         return fast_callable(self, etb)
#   12059
#   12060     def show(self):
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/symbolic/expression_conversions.py in fast_callable(ex, etb)
#    1927
#    1928     """
# -> 1929     return FastCallableConverter(ex, etb)()
#    1930
#    1931 class RingConverter(Converter):
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/symbolic/expression_conversions.py in __call__(self, ex)
#     215             if getattr(self, 'use_fake_div', False) and (operator is _operator.mul or operator is mul_vararg):
#     216                 div = self.get_fake_div(ex)
# --> 217                 return self.arithmetic(div, div.operator())
#     218             return self.arithmetic(ex, operator)
#     219         elif operator in relation_operators:
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/symbolic/expression_conversions.py in arithmetic(self, ex, operator)
#    1855         elif operator == mul_vararg:
#    1856             operator = _operator.mul
# -> 1857         return reduce(lambda x,y: self.etb.call(operator, x,y), operands)
#    1858
#    1859     def symbol(self, ex):
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/symbolic/expression_conversions.py in <lambda>(x, y)
#    1855         elif operator == mul_vararg:
#    1856             operator = _operator.mul
# -> 1857         return reduce(lambda x,y: self.etb.call(operator, x,y), operands)
#    1858
#    1859     def symbol(self, ex):
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/ext/fast_callable.pyx in sage.ext.fast_callable.ExpressionTreeBuilder.call (build/cythonized/sage/ext/fast_callable.c:7205)()
#     742             return self(base)**exponent
#     743         else:
# --> 744             return ExpressionCall(self, fn, [self(a) for a in args])
#     745
#     746     def choice(self, cond, iftrue, iffalse):
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/ext/fast_callable.pyx in sage.ext.fast_callable.ExpressionTreeBuilder.__call__ (build/cythonized/sage/ext/fast_callable.c:6321)()
#     616             return self.constant(x)
#     617
# --> 618         return fc(self)
#     619
#     620     def _clean_var(self, v):
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/symbolic/expression.pyx in sage.symbolic.expression.Expression._fast_callable_ (build/cythonized/sage/symbolic/expression.cpp:64777)()
#   12056         """
#   12057         from sage.symbolic.expression_conversions import fast_callable
# > 12058         return fast_callable(self, etb)
#   12059
#   12060     def show(self):
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/symbolic/expression_conversions.py in fast_callable(ex, etb)
#    1927
#    1928     """
# -> 1929     return FastCallableConverter(ex, etb)()
#    1930
#    1931 class RingConverter(Converter):
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/symbolic/expression_conversions.py in __call__(self, ex)
#     224             return self.tuple(ex)
#     225         else:
# --> 226             return self.composition(ex, operator)
#     227
#     228     def get_fake_div(self, ex):
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/symbolic/expression_conversions.py in composition(self, ex, function)
#    1893             {arctan2}(v_0, v_1)
#    1894         """
# -> 1895         return self.etb.call(function, *ex.operands())
#    1896
#    1897     def tuple(self, ex):
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/ext/fast_callable.pyx in sage.ext.fast_callable.ExpressionTreeBuilder.call (build/cythonized/sage/ext/fast_callable.c:7205)()
#     742             return self(base)**exponent
#     743         else:
# --> 744             return ExpressionCall(self, fn, [self(a) for a in args])
#     745
#     746     def choice(self, cond, iftrue, iffalse):
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/ext/fast_callable.pyx in sage.ext.fast_callable.ExpressionTreeBuilder.__call__ (build/cythonized/sage/ext/fast_callable.c:6321)()
#     616             return self.constant(x)
#     617
# --> 618         return fc(self)
#     619
#     620     def _clean_var(self, v):
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/symbolic/expression.pyx in sage.symbolic.expression.Expression._fast_callable_ (build/cythonized/sage/symbolic/expression.cpp:64777)()
#   12056         """
#   12057         from sage.symbolic.expression_conversions import fast_callable
# > 12058         return fast_callable(self, etb)
#   12059
#   12060     def show(self):
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/symbolic/expression_conversions.py in fast_callable(ex, etb)
#    1927
#    1928     """
# -> 1929     return FastCallableConverter(ex, etb)()
#    1930
#    1931 class RingConverter(Converter):
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/symbolic/expression_conversions.py in __call__(self, ex)
#     215             if getattr(self, 'use_fake_div', False) and (operator is _operator.mul or operator is mul_vararg):
#     216                 div = self.get_fake_div(ex)
# --> 217                 return self.arithmetic(div, div.operator())
#     218             return self.arithmetic(ex, operator)
#     219         elif operator in relation_operators:
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/symbolic/expression_conversions.py in arithmetic(self, ex, operator)
#    1855         elif operator == mul_vararg:
#    1856             operator = _operator.mul
# -> 1857         return reduce(lambda x,y: self.etb.call(operator, x,y), operands)
#    1858
#    1859     def symbol(self, ex):
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/symbolic/expression_conversions.py in <lambda>(x, y)
#    1855         elif operator == mul_vararg:
#    1856             operator = _operator.mul
# -> 1857         return reduce(lambda x,y: self.etb.call(operator, x,y), operands)
#    1858
#    1859     def symbol(self, ex):
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/ext/fast_callable.pyx in sage.ext.fast_callable.ExpressionTreeBuilder.call (build/cythonized/sage/ext/fast_callable.c:7205)()
#     742             return self(base)**exponent
#     743         else:
# --> 744             return ExpressionCall(self, fn, [self(a) for a in args])
#     745
#     746     def choice(self, cond, iftrue, iffalse):
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/ext/fast_callable.pyx in sage.ext.fast_callable.ExpressionTreeBuilder.__call__ (build/cythonized/sage/ext/fast_callable.c:6321)()
#     616             return self.constant(x)
#     617
# --> 618         return fc(self)
#     619
#     620     def _clean_var(self, v):
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/symbolic/expression.pyx in sage.symbolic.expression.Expression._fast_callable_ (build/cythonized/sage/symbolic/expression.cpp:64777)()
#   12056         """
#   12057         from sage.symbolic.expression_conversions import fast_callable
# > 12058         return fast_callable(self, etb)
#   12059
#   12060     def show(self):
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/symbolic/expression_conversions.py in fast_callable(ex, etb)
#    1927
#    1928     """
# -> 1929     return FastCallableConverter(ex, etb)()
#    1930
#    1931 class RingConverter(Converter):
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/symbolic/expression_conversions.py in __call__(self, ex)
#     216                 div = self.get_fake_div(ex)
#     217                 return self.arithmetic(div, div.operator())
# --> 218             return self.arithmetic(ex, operator)
#     219         elif operator in relation_operators:
#     220             return self.relation(ex, operator)
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/symbolic/expression_conversions.py in arithmetic(self, ex, operator)
#    1855         elif operator == mul_vararg:
#    1856             operator = _operator.mul
# -> 1857         return reduce(lambda x,y: self.etb.call(operator, x,y), operands)
#    1858
#    1859     def symbol(self, ex):
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/symbolic/expression_conversions.py in <lambda>(x, y)
#    1855         elif operator == mul_vararg:
#    1856             operator = _operator.mul
# -> 1857         return reduce(lambda x,y: self.etb.call(operator, x,y), operands)
#    1858
#    1859     def symbol(self, ex):
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/ext/fast_callable.pyx in sage.ext.fast_callable.ExpressionTreeBuilder.call (build/cythonized/sage/ext/fast_callable.c:7205)()
#     742             return self(base)**exponent
#     743         else:
# --> 744             return ExpressionCall(self, fn, [self(a) for a in args])
#     745
#     746     def choice(self, cond, iftrue, iffalse):
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/ext/fast_callable.pyx in sage.ext.fast_callable.ExpressionTreeBuilder.__call__ (build/cythonized/sage/ext/fast_callable.c:6321)()
#     616             return self.constant(x)
#     617
# --> 618         return fc(self)
#     619
#     620     def _clean_var(self, v):
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/symbolic/expression.pyx in sage.symbolic.expression.Expression._fast_callable_ (build/cythonized/sage/symbolic/expression.cpp:64777)()
#   12056         """
#   12057         from sage.symbolic.expression_conversions import fast_callable
# > 12058         return fast_callable(self, etb)
#   12059
#   12060     def show(self):
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/symbolic/expression_conversions.py in fast_callable(ex, etb)
#    1927
#    1928     """
# -> 1929     return FastCallableConverter(ex, etb)()
#    1930
#    1931 class RingConverter(Converter):
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/symbolic/expression_conversions.py in __call__(self, ex)
#     210         operator = ex.operator()
#     211         if operator is None:
# --> 212             return self.symbol(ex)
#     213
#     214         if operator in arithmetic_operators:
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/symbolic/expression_conversions.py in symbol(self, ex)
#    1876             ValueError: Variable 'z' not found
#    1877         """
# -> 1878         return self.etb.var(SR(ex))
#    1879
#    1880     def composition(self, ex, function):
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/ext/fast_callable.pyx in sage.ext.fast_callable.ExpressionTreeBuilder.var (build/cythonized/sage/ext/fast_callable.c:6792)()
#     688             ind = self._vars.index(var_name)
#     689         except ValueError:
# --> 690             raise ValueError("Variable '%s' not found" % var_name)
#     691         return ExpressionVariable(self, ind)
#     692
#
# ValueError: Variable 'mu' not found

# %%
mumax=6
Ks= 1
D=4
Y=0.8
Sf=20
S=2

plot((Y*(Sf- Ks*D/(mumax-D)), Ks*D/(mumax-D)),(t,0,30))
# Out:
# Graphics object consisting of 2 graphics primitives

# %% [markdown]
# Simulação:

# %%
import numpy as np
import pandas as pd
# %display typeset

# %%
def model(t, y, params):
    X, S = y
    mu, D, Sf, Y, mumax, Ks = params
    return [
        mu*X - D*X, #dX/dt
        D*Sf - D*S -(mu*X/Y) # dS/dt
    ]

# %%
mumax=6
Ks= 1
D=4
Y=0.8
Sf=20
mu = mumax*S/(Ks+S)

# %%
T = ode_solver()
T.function = model
T.algorithm='rk8pd'
inits = [0.05, 10.0]
tspan = [0,100]
T.ode_solve(tspan, inits, num_points=200, params=[mu, D, Sf, Y, mumax, Ks])

# %%
def get_sim_array(sol):
    sim = np.array([y for t,y in sol])
    return sim
get_sim_array(T.solution)
# Out:
# array([[ 0.5       ,  5.        ],
#        [ 0.55081541,  8.11621948],
#        [ 0.61562674, 10.51158834],
#        [ 0.69263532, 12.34393666],
#        [ 0.78215613, 13.73403788],
#        [ 0.88524705, 14.77493474],
#        [ 1.00338647, 15.53827085],
#        [ 1.13837857, 16.07902635],
#        [ 1.29232917, 16.43914384],
#        [ 1.46764886, 16.65032507],
#        [ 1.66706816, 16.73619295],
#        [ 1.89365784, 16.7139647 ],
#        [ 2.15085049, 16.59574778],
#        [ 2.44245967, 16.38954618],
#        [ 2.77269235, 16.10004718],
#        [ 3.14614899, 15.72924617],
#        [ 3.5678024 , 15.2769597 ],
#        [ 4.04294248, 14.74127354],
#        [ 4.57706664, 14.11897487],
#        [ 5.17568431, 13.40602649],
#        [ 5.8439852 , 12.59816051],
#        [ 6.58628994, 11.6917045 ],
#        [ 7.40514914, 10.68481624],
#        [ 8.29986879,  9.57941154],
#        [ 9.26409739,  8.3842462 ],
#        [10.2819143 ,  7.11985685],
#        [11.32176112,  5.82618666],
#        [12.32842009,  4.5726435 ],
#        [13.21821423,  3.46412391],
#        [13.89623927,  2.61949216],
#        [14.31548302,  2.09769564],
#        [14.52305734,  1.8399864 ],
#        [14.61028607,  1.73232013],
#        [14.64406174,  1.69116723],
#        [14.6568814 ,  1.67597339],
#        [14.66186564,  1.67039007],
#        [14.66393772,  1.66830384],
#        [14.66490229,  1.66749053],
#        [14.66542142,  1.66714723],
#        [14.66574285,  1.66698345],
#        [14.6659636 ,  1.66689287],
#        [14.66612498,  1.66683552],
#        [14.66624689,  1.66679556],
#        [14.66634049,  1.66676611],
#        [14.66641291,  1.66674378],
#        [14.66646913,  1.6667266 ],
#        [14.66651286,  1.6667133 ],
#        [14.6665469 ,  1.66670297],
#        [14.66657339,  1.66669494],
#        [14.66659403,  1.66668868],
#        [14.6666101 ,  1.66668381],
#        [14.66662261,  1.66668002],
#        [14.66663235,  1.66667706],
#        [14.66663994,  1.66667476],
#        [14.66664586,  1.66667297],
#        [14.66665046,  1.66667158],
#        [14.66665404,  1.66667049],
#        [14.66665684,  1.66666965],
#        [14.66665901,  1.66666899],
#        [14.6666607 ,  1.66666847],
#        [14.66666202,  1.66666807],
#        [14.66666305,  1.66666776],
#        [14.66666385,  1.66666752],
#        [14.66666447,  1.66666733],
#        [14.66666496,  1.66666718],
#        [14.66666534,  1.66666707],
#        [14.66666563,  1.66666698],
#        [14.66666586,  1.66666691],
#        [14.66666604,  1.66666686],
#        [14.66666618,  1.66666681],
#        [14.66666629,  1.66666678],
#        [14.66666637,  1.66666676],
#        [14.66666644,  1.66666674],
#        [14.66666649,  1.66666672],
#        [14.66666653,  1.66666671],
#        [14.66666656,  1.6666667 ],
#        [14.66666658,  1.66666669],
#        [14.6666666 ,  1.66666669],
#        [14.66666662,  1.66666668],
#        [14.66666663,  1.66666668],
#        [14.66666664,  1.66666668],
#        [14.66666664,  1.66666667],
#        [14.66666665,  1.66666667],
#        [14.66666665,  1.66666667],
#        [14.66666666,  1.66666667],
#        [14.66666666,  1.66666667],
#        [14.66666666,  1.66666667],
#        [14.66666666,  1.66666667],
#        [14.66666666,  1.66666667],
#        [14.66666666,  1.66666667],
#        [14.66666666,  1.66666667],
#        [14.66666666,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667]])

# %%
def plot_sol(sol):
    sim = get_sim_array(sol)
    P = list_plot(sim[:,0],legend_label='X')
    colors = ['blue','green']
    for i,var in enumerate(['S']):
        P += list_plot(sim[:,i+1],color=colors[i+1],legend_label=var)
   
    show(P, figsize=(16, 8))
plot_sol(T.solution)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
T = ode_solver()
T.function = model
T.algorithm='rk8pd'
inits = [14.6666666666667, 1.66666666666667]
tspan = [0,100]
T.ode_solve(tspan, inits, num_points=200, params=[mu, D, Sf, Y, mumax, Ks])

# %%
def get_sim_array(sol):
    sim = np.array([y for t,y in sol])
    return sim
get_sim_array(T.solution)
# Out:
# array([[14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667],
#        [14.66666667,  1.66666667]])

# %%
def plot_sol(sol):
    sim = get_sim_array(sol)
    P = list_plot(sim[:,0],legend_label='X')
    colors = ['blue','green']
    for i,var in enumerate(['S']):
        P += list_plot(sim[:,i+1],color=colors[i+1],legend_label=var)
   
    show(P, figsize=(16, 8))
plot_sol(T.solution)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
T = ode_solver()
T.function = model
T.algorithm='rk8pd'
inits = [1, 1]
tspan = [0,100]
T.ode_solve(tspan, inits, num_points=200, params=[mu, D, Sf, Y, mumax, Ks])

# %%
def get_sim_array(sol):
    sim = np.array([y for t,y in sol])
    return sim
get_sim_array(T.solution)
# Out:
# array([[ 1.        ,  1.        ],
#        [ 1.        , 16.34779872],
#        [ 1.        , 18.42489741],
#        [ 1.        , 18.70600215],
#        [ 1.        , 18.74404554],
#        [ 1.        , 18.74919415],
#        [ 1.        , 18.74989094],
#        [ 1.        , 18.74998524],
#        [ 1.        , 18.749998  ],
#        [ 1.        , 18.74999973],
#        [ 1.        , 18.74999996],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ],
#        [ 1.        , 18.75      ]])

# %% [markdown]
# **Observação: a concentração de células (X) não evolui porque, no cálculo acima, mu=D, e consequentemente X não irá evoluir**

# %%
mumax = 1.6   
Ks = 1.00     
Y = 0.8     
Sf = 20.0    
D = 1.00
mu = mumax*S/(Ks+S)

# %%
T = ode_solver()
T.function = model
T.algorithm='rk8pd'
inits = [0.05, 10]
tspan = [0,80]
T.ode_solve(tspan, inits, num_points=200, params=[mu, D, Sf, Y, mumax, Ks])

# %%
def get_sim_array(sol):
    sim = np.array([y for t,y in sol])
    return sim
get_sim_array(T.solution)
# Out:
# array([[ 0.05      , 10.        ],
#        [ 0.05135127, 13.27450545],
#        [ 0.05273906, 15.4688696 ],
#        [ 0.05416435, 16.93917708],
#        [ 0.05562817, 17.92411814],
#        [ 0.05713154, 18.5836912 ],
#        [ 0.05867554, 19.02514591],
#        [ 0.06026127, 19.32037341],
#        [ 0.06188986, 19.51756327],
#        [ 0.06356246, 19.64901744],
#        [ 0.06528026, 19.73638802],
#        [ 0.06704448, 19.79418833],
#        [ 0.06885639, 19.8321464 ],
#        [ 0.07071726, 19.85678257],
#        [ 0.07262842, 19.87246695],
#        [ 0.07459123, 19.88212836],
#        [ 0.07660709, 19.88772941],
#        [ 0.07867743, 19.89058507],
#        [ 0.08080372, 19.89157615],
#        [ 0.08298747, 19.89129242],
#        [ 0.08523024, 19.89012854],
#        [ 0.08753363, 19.88834835],
#        [ 0.08989926, 19.88612802],
#        [ 0.09232882, 19.8835849 ],
#        [ 0.09482404, 19.88079689],
#        [ 0.0973867 , 19.87781546],
#        [ 0.10001862, 19.87467431],
#        [ 0.10272166, 19.8713952 ],
#        [ 0.10549775, 19.86799192],
#        [ 0.10834887, 19.86447282],
#        [ 0.11127705, 19.86084263],
#        [ 0.11428435, 19.85710363],
#        [ 0.11737293, 19.8532564 ],
#        [ 0.12054499, 19.84930038],
#        [ 0.12380276, 19.84523422],
#        [ 0.12714858, 19.84105601],
#        [ 0.13058482, 19.83676343],
#        [ 0.13411393, 19.83235387],
#        [ 0.13773841, 19.82782449],
#        [ 0.14146085, 19.82317227],
#        [ 0.14528389, 19.81839402],
#        [ 0.14921024, 19.81348645],
#        [ 0.15324271, 19.80844611],
#        [ 0.15738416, 19.80326947],
#        [ 0.16163753, 19.79795287],
#        [ 0.16600585, 19.79249254],
#        [ 0.17049222, 19.78688462],
#        [ 0.17509984, 19.78112513],
#        [ 0.17983199, 19.77520997],
#        [ 0.18469202, 19.76913495],
#        [ 0.18968339, 19.76289574],
#        [ 0.19480967, 19.7564879 ],
#        [ 0.20007447, 19.7499069 ],
#        [ 0.20548157, 19.74314803],
#        [ 0.21103479, 19.73620651],
#        [ 0.21673809, 19.72907738],
#        [ 0.22259553, 19.72175559],
#        [ 0.22861126, 19.71423592],
#        [ 0.23478957, 19.70651303],
#        [ 0.24113485, 19.69858143],
#        [ 0.24765162, 19.69043547],
#        [ 0.25434451, 19.68206937],
#        [ 0.26121827, 19.67347716],
#        [ 0.2682778 , 19.66465275],
#        [ 0.27552811, 19.65558986],
#        [ 0.28297437, 19.64628203],
#        [ 0.29062187, 19.63672266],
#        [ 0.29847604, 19.62690495],
#        [ 0.30654248, 19.6168219 ],
#        [ 0.31482691, 19.60646636],
#        [ 0.32333524, 19.59583095],
#        [ 0.3320735 , 19.58490812],
#        [ 0.34104792, 19.5736901 ],
#        [ 0.35026488, 19.5621689 ],
#        [ 0.35973093, 19.55033634],
#        [ 0.3694528 , 19.53818399],
#        [ 0.37943742, 19.52570323],
#        [ 0.38969187, 19.51288517],
#        [ 0.40022345, 19.49972069],
#        [ 0.41103965, 19.48620044],
#        [ 0.42214816, 19.4723148 ],
#        [ 0.43355688, 19.4580539 ],
#        [ 0.44527393, 19.44340758],
#        [ 0.45730764, 19.42836545],
#        [ 0.46966656, 19.41291679],
#        [ 0.48235949, 19.39705063],
#        [ 0.49539545, 19.38075568],
#        [ 0.50878372, 19.36402036],
#        [ 0.5225338 , 19.34683275],
#        [ 0.53665549, 19.32918064],
#        [ 0.55115882, 19.31105148],
#        [ 0.56605411, 19.29243236],
#        [ 0.58135195, 19.27331006],
#        [ 0.59706322, 19.25367097],
#        [ 0.6131991 , 19.23350113],
#        [ 0.62977105, 19.21278619],
#        [ 0.64679087, 19.19151142],
#        [ 0.66427065, 19.16966169],
#        [ 0.68222283, 19.14722146],
#        [ 0.70066018, 19.12417477],
#        [ 0.7195958 , 19.10050524],
#        [ 0.73904317, 19.07619603],
#        [ 0.75901611, 19.05122986],
#        [ 0.77952883, 19.02558896],
#        [ 0.80059591, 18.99925511],
#        [ 0.82223234, 18.97220958],
#        [ 0.8444535 , 18.94443313],
#        [ 0.8672752 , 18.915906  ],
#        [ 0.89071366, 18.88660793],
#        [ 0.91478556, 18.85651806],
#        [ 0.939508  , 18.82561499],
#        [ 0.96489859, 18.79387677],
#        [ 0.99097536, 18.7612808 ],
#        [ 1.01775687, 18.72780391],
#        [ 1.04526216, 18.6934223 ],
#        [ 1.07351079, 18.65811151],
#        [ 1.10252286, 18.62184643],
#        [ 1.13231898, 18.58460127],
#        [ 1.16292036, 18.54634955],
#        [ 1.19434875, 18.50706406],
#        [ 1.22662651, 18.46671686],
#        [ 1.25977659, 18.42527927],
#        [ 1.29382256, 18.3827218 ],
#        [ 1.32878863, 18.33901421],
#        [ 1.36469968, 18.29412539],
#        [ 1.40158124, 18.24802344],
#        [ 1.43945954, 18.20067557],
#        [ 1.47836152, 18.1520481 ],
#        [ 1.51831484, 18.10210645],
#        [ 1.55934791, 18.05081511],
#        [ 1.60148992, 17.99813761],
#        [ 1.64477083, 17.94403647],
#        [ 1.68922142, 17.88847322],
#        [ 1.73487331, 17.83140836],
#        [ 1.78175897, 17.77280129],
#        [ 1.82991172, 17.71261035],
#        [ 1.87936583, 17.65079272],
#        [ 1.93015645, 17.58730444],
#        [ 1.9823197 , 17.52210037],
#        [ 2.03589269, 17.45513413],
#        [ 2.09091352, 17.3863581 ],
#        [ 2.1474213 , 17.31572338],
#        [ 2.20545623, 17.24317972],
#        [ 2.26505957, 17.16867553],
#        [ 2.32627372, 17.09215785],
#        [ 2.38914221, 17.01357224],
#        [ 2.45370974, 16.93286282],
#        [ 2.52002224, 16.8499722 ],
#        [ 2.58812686, 16.76484143],
#        [ 2.65807203, 16.67740996],
#        [ 2.7299075 , 16.58761562],
#        [ 2.80368435, 16.49539456],
#        [ 2.87945506, 16.40068118],
#        [ 2.95727349, 16.30340813],
#        [ 3.037195  , 16.20350625],
#        [ 3.11927642, 16.10090447],
#        [ 3.20357613, 15.99552984],
#        [ 3.29015407, 15.88730741],
#        [ 3.37907181, 15.77616024],
#        [ 3.47039259, 15.66200926],
#        [ 3.56418135, 15.54477331],
#        [ 3.66050479, 15.42436901],
#        [ 3.75943141, 15.30071073],
#        [ 3.86103157, 15.17371054],
#        [ 3.9653775 , 15.04327812],
#        [ 4.07254343, 14.90932071],
#        [ 4.18260556, 14.77174304],
#        [ 4.29564217, 14.63044729],
#        [ 4.41173363, 14.48533296],
#        [ 4.53096252, 14.33629685],
#        [ 4.65341361, 14.18323299],
#        [ 4.77917399, 14.02603251],
#        [ 4.9083331 , 13.86458363],
#        [ 5.04098278, 13.69877152],
#        [ 5.17721738, 13.52847828],
#        [ 5.31713377, 13.35358279],
#        [ 5.46083146, 13.17396068],
#        [ 5.60841263, 12.98948421],
#        [ 5.75998225, 12.80002219],
#        [ 5.9156481 , 12.60543988],
#        [ 6.07552088, 12.40559891],
#        [ 6.23971428, 12.20035715],
#        [ 6.40834508, 11.98956865],
#        [ 6.58153319, 11.77308351],
#        [ 6.75940179, 11.55074777],
#        [ 6.94207735, 11.32240331],
#        [ 7.12968979, 11.08788776],
#        [ 7.32237254, 10.84703432],
#        [ 7.52026262, 10.59967173],
#        [ 7.72350075, 10.34562406],
#        [ 7.93223148, 10.08471065],
#        [ 8.14660324,  9.81674595],
#        [ 8.36676848,  9.5415394 ],
#        [ 8.59288378,  9.25889528],
#        [ 8.82510993,  8.96861258],
#        [ 9.06361209,  8.67048488],
#        [ 9.30855987,  8.36430016],
#        [ 9.56012746,  8.04984067],
#        [ 9.81849377,  7.72688279],
#        [10.08384253,  7.39519684],
#        [10.35636244,  7.05454694]])

# %%
def plot_sol(sol):
    sim = get_sim_array(sol)
    P = list_plot(sim[:,0],legend_label='X')
    colors = ['blue','green']
    for i,var in enumerate(['S']):
        P += list_plot(sim[:,i+1],color=colors[i+1],legend_label=var)
   
    show(P, figsize=(16, 8))
plot_sol(T.solution)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
mumax = 1.6   
Ks = 1.00     
Y = 0.3    
Sf = 20.0     
D = 1.00
mu = mumax*S/(Ks+S)

# %%
T = ode_solver()
T.function = model
T.algorithm='rk8pd'
inits = [0.05, 10]
tspan = [0,75]
T.ode_solve(tspan, inits, num_points=200, params=[mu, D, Sf, Y, mumax, Ks])

# %%
def get_sim_array(sol):
    sim = np.array([y for t,y in sol])
    return sim
get_sim_array(T.solution)
# Out:
# array([[ 0.05      , 10.        ],
#        [ 0.05126576, 13.07076957],
#        [ 0.05256355, 15.17985038],
#        [ 0.05389421, 16.62793671],
#        [ 0.05525855, 17.62169161],
#        [ 0.05665742, 18.30315142],
#        [ 0.05809171, 18.76993525],
#        [ 0.05956231, 19.08913469],
#        [ 0.06107014, 19.30686003],
#        [ 0.06261614, 19.45480138],
#        [ 0.06420127, 19.55473793],
#        [ 0.06582653, 19.62163719],
#        [ 0.06749294, 19.66578507],
#        [ 0.06920153, 19.6942498 ],
#        [ 0.07095338, 19.71188814],
#        [ 0.07274957, 19.72203689],
#        [ 0.07459123, 19.72698815],
#        [ 0.07647952, 19.728316  ],
#        [ 0.07841561, 19.72710099],
#        [ 0.08040071, 19.72408443],
#        [ 0.08243606, 19.71977446],
#        [ 0.08452294, 19.71451892],
#        [ 0.08666265, 19.70855545],
#        [ 0.08885653, 19.7020459 ],
#        [ 0.09110594, 19.6951    ],
#        [ 0.0934123 , 19.68779163],
#        [ 0.09577704, 19.68016996],
#        [ 0.09820165, 19.6722672 ],
#        [ 0.10068764, 19.66410377],
#        [ 0.10323655, 19.65569205],
#        [ 0.10585   , 19.64703876],
#        [ 0.10852961, 19.63814674],
#        [ 0.11127705, 19.62901609],
#        [ 0.11409404, 19.61964501],
#        [ 0.11698234, 19.61003032],
#        [ 0.11994376, 19.60016784],
#        [ 0.12298016, 19.59005267],
#        [ 0.12609341, 19.57967936],
#        [ 0.12928548, 19.56904202],
#        [ 0.13255836, 19.55813442],
#        [ 0.13591409, 19.54695002],
#        [ 0.13935477, 19.53548202],
#        [ 0.14288256, 19.52372339],
#        [ 0.14649965, 19.51166687],
#        [ 0.1502083 , 19.49930499],
#        [ 0.15401084, 19.48663006],
#        [ 0.15790965, 19.4736342 ],
#        [ 0.16190715, 19.46030929],
#        [ 0.16600585, 19.44664703],
#        [ 0.1702083 , 19.43263888],
#        [ 0.17451715, 19.4182761 ],
#        [ 0.17893507, 19.40354972],
#        [ 0.18346483, 19.38845052],
#        [ 0.18810927, 19.37296908],
#        [ 0.19287128, 19.35709573],
#        [ 0.19775384, 19.34082054],
#        [ 0.20276   , 19.32413333],
#        [ 0.20789289, 19.30702369],
#        [ 0.21315573, 19.28948091],
#        [ 0.21855179, 19.27149404],
#        [ 0.22408445, 19.25305182],
#        [ 0.22975718, 19.23414274],
#        [ 0.23557351, 19.21475497],
#        [ 0.24153708, 19.1948764 ],
#        [ 0.24765162, 19.1744946 ],
#        [ 0.25392095, 19.15359683],
#        [ 0.26034899, 19.13217003],
#        [ 0.26693976, 19.11020081],
#        [ 0.27369737, 19.08767543],
#        [ 0.28062605, 19.06457983],
#        [ 0.28773013, 19.04089955],
#        [ 0.29501406, 19.01661981],
#        [ 0.30248237, 18.99172542],
#        [ 0.31013975, 18.96620083],
#        [ 0.31799098, 18.94003008],
#        [ 0.32604096, 18.91319681],
#        [ 0.33429472, 18.88568426],
#        [ 0.34275743, 18.85747522],
#        [ 0.35143438, 18.82855207],
#        [ 0.36033098, 18.79889672],
#        [ 0.3694528 , 18.76849065],
#        [ 0.37880555, 18.73731484],
#        [ 0.38839506, 18.70534982],
#        [ 0.39822732, 18.67257559],
#        [ 0.4083085 , 18.63897168],
#        [ 0.41864487, 18.60451709],
#        [ 0.42924292, 18.56919027],
#        [ 0.44010926, 18.53296915],
#        [ 0.45125067, 18.49583108],
#        [ 0.46267414, 18.45775287],
#        [ 0.47438679, 18.41871069],
#        [ 0.48639595, 18.37868016],
#        [ 0.49870912, 18.33763626],
#        [ 0.511334  , 18.29555332],
#        [ 0.52427849, 18.25240505],
#        [ 0.53755066, 18.20816447],
#        [ 0.55115882, 18.16280394],
#        [ 0.56511147, 18.1162951 ],
#        [ 0.57941734, 18.06860888],
#        [ 0.59408536, 18.01971548],
#        [ 0.6091247 , 17.96958434],
#        [ 0.62454476, 17.91818412],
#        [ 0.64035519, 17.8654827 ],
#        [ 0.65656586, 17.81144714],
#        [ 0.6731869 , 17.75604366],
#        [ 0.69022871, 17.69923764],
#        [ 0.70770193, 17.64099356],
#        [ 0.72561749, 17.58127503],
#        [ 0.74398659, 17.52004471],
#        [ 0.7628207 , 17.45726435],
#        [ 0.78213159, 17.39289469],
#        [ 0.80193135, 17.3268955 ],
#        [ 0.82223234, 17.25922554],
#        [ 0.84304725, 17.1898425 ],
#        [ 0.86438909, 17.11870303],
#        [ 0.88627121, 17.04576265],
#        [ 0.90870727, 16.97097577],
#        [ 0.9317113 , 16.89429566],
#        [ 0.95529769, 16.81567438],
#        [ 0.97948116, 16.73506279],
#        [ 1.00427685, 16.65241051],
#        [ 1.02970024, 16.56766588],
#        [ 1.05576722, 16.48077593],
#        [ 1.0824941 , 16.39168635],
#        [ 1.10989756, 16.30034145],
#        [ 1.13799475, 16.20668415],
#        [ 1.16680323, 16.1106559 ],
#        [ 1.19634099, 16.01219669],
#        [ 1.22662651, 15.91124497],
#        [ 1.25767871, 15.80773764],
#        [ 1.289517  , 15.70161001],
#        [ 1.32216127, 15.59279575],
#        [ 1.35563195, 15.48122685],
#        [ 1.38994993, 15.36683356],
#        [ 1.42513668, 15.24954439],
#        [ 1.46121419, 15.12928604],
#        [ 1.498205  , 15.00598333],
#        [ 1.53613224, 14.87955919],
#        [ 1.57501962, 14.74993462],
#        [ 1.61489143, 14.61702858],
#        [ 1.6557726 , 14.48075801],
#        [ 1.69768868, 14.34103773],
#        [ 1.74066587, 14.19778042],
#        [ 1.78473104, 14.05089653],
#        [ 1.82991172, 13.90029426],
#        [ 1.87623616, 13.74587947],
#        [ 1.9237333 , 13.58755566],
#        [ 1.97243284, 13.42522386],
#        [ 2.02236522, 13.25878261],
#        [ 2.07356164, 13.08812788],
#        [ 2.1260541 , 12.913153  ],
#        [ 2.17987542, 12.73374861],
#        [ 2.23505922, 12.54980258],
#        [ 2.29164002, 12.36119994],
#        [ 2.34965316, 12.16782279],
#        [ 2.40913491, 11.96955028],
#        [ 2.47012246, 11.76625848],
#        [ 2.5326539 , 11.55782032],
#        [ 2.59676834, 11.34410553],
#        [ 2.66250585, 11.12498052],
#        [ 2.7299075 , 10.90030833],
#        [ 2.79901544, 10.66994854],
#        [ 2.86987285, 10.43375716],
#        [ 2.94252403, 10.19158657],
#        [ 3.01701438,  9.9432854 ],
#        [ 3.09339046,  9.68869846],
#        [ 3.17170001,  9.42766662],
#        [ 3.25199198,  9.16002672],
#        [ 3.33431655,  8.88561149],
#        [ 3.41872518,  8.60424941],
#        [ 3.50527062,  8.31576461],
#        [ 3.59400697,  8.01997678],
#        [ 3.68498968,  7.71670105],
#        [ 3.77827564,  7.40574786],
#        [ 3.87392315,  7.08692285],
#        [ 3.97199198,  6.76002674],
#        [ 4.07254343,  6.42485522],
#        [ 4.17564036,  6.0811988 ],
#        [ 4.2813472 ,  5.72884267],
#        [ 4.38973002,  5.3675666 ],
#        [ 4.50085657,  4.99714478],
#        [ 4.61479629,  4.6173457 ],
#        [ 4.73162042,  4.22793195],
#        [ 4.85140196,  3.82866014],
#        [ 4.97421578,  3.41928073],
#        [ 5.10013865,  2.99953782],
#        [ 5.22924928,  2.56916907],
#        [ 5.36162835,  2.12790548],
#        [ 5.49735862,  1.67547126],
#        [ 5.63652492,  1.2115836 ],
#        [ 5.77921423,  0.73595258],
#        [ 5.92551573,  0.2482809 ],
#        [ 6.07552088, -0.25173625],
#        [ 6.22932342, -0.7644114 ],
#        [ 6.38701949, -1.29006497],
#        [ 6.54870766, -1.82902554],
#        [ 6.71448898, -2.38162995],
#        [ 6.88446708, -2.94822361],
#        [ 7.0587482 , -3.52916065],
#        [ 7.23744126, -4.12480419],
#        [ 7.42065796, -4.73552652]])

# %%
def plot_sol(sol):
    sim = get_sim_array(sol)
    P = list_plot(sim[:,0],legend_label='X')
    colors = ['blue','green']
    for i,var in enumerate(['S']):
        P += list_plot(sim[:,i+1],color=colors[i+1],legend_label=var)
   
    show(P, figsize=(16, 8))
plot_sol(T.solution)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
mumax = 1.6
Ks = 1.0
D = 1.0
Y = 0.8
Sf = 20.0
mu = mumax*S/(Ks+S)

# %%
T = ode_solver()
T.function = model
T.algorithm='rk8pd'
inits = [14.6666666666667, 1.66666666666667]
tspan = [0,100]
T.ode_solve(tspan, inits, num_points=200, params=[mu, D, Sf, Y, mumax, Ks])

# %%
def get_sim_array(sol):
    sim = np.array([y for t,y in sol])
    return sim
get_sim_array(T.solution)
# Out:
# array([[ 1.46666667e+01,  1.66666667e+00],
#        [ 1.51637950e+01,  1.04525625e+00],
#        [ 1.56777736e+01,  4.02783061e-01],
#        [ 1.62091735e+01, -2.61466831e-01],
#        [ 1.67585852e+01, -9.48231550e-01],
#        [ 1.73266194e+01, -1.65827424e+00],
#        [ 1.79139071e+01, -2.39238390e+00],
#        [ 1.85211010e+01, -3.15137629e+00],
#        [ 1.91488759e+01, -3.93609482e+00],
#        [ 1.97979292e+01, -4.74741147e+00],
#        [ 2.04689822e+01, -5.58622779e+00],
#        [ 2.11627807e+01, -6.45347589e+00],
#        [ 2.18800956e+01, -7.35011946e+00],
#        [ 2.26217239e+01, -8.27715486e+00],
#        [ 2.33884898e+01, -9.23561223e+00],
#        [ 2.41812453e+01, -1.02265566e+01],
#        [ 2.50008714e+01, -1.12510892e+01],
#        [ 2.58482787e+01, -1.23103484e+01],
#        [ 2.67244091e+01, -1.34055113e+01],
#        [ 2.76302360e+01, -1.45377949e+01],
#        [ 2.85667659e+01, -1.57084574e+01],
#        [ 2.95350397e+01, -1.69187996e+01],
#        [ 3.05361332e+01, -1.81701665e+01],
#        [ 3.15711589e+01, -1.94639487e+01],
#        [ 3.26412670e+01, -2.08015837e+01],
#        [ 3.37476464e+01, -2.21845580e+01],
#        [ 3.48915267e+01, -2.36144084e+01],
#        [ 3.60741790e+01, -2.50927237e+01],
#        [ 3.72969174e+01, -2.66211467e+01],
#        [ 3.85611006e+01, -2.82013758e+01],
#        [ 3.98681335e+01, -2.98351669e+01],
#        [ 4.12194684e+01, -3.15243355e+01],
#        [ 4.26166070e+01, -3.32707587e+01],
#        [ 4.40611017e+01, -3.50763771e+01],
#        [ 4.55545577e+01, -3.69431972e+01],
#        [ 4.70986346e+01, -3.88732933e+01],
#        [ 4.86950482e+01, -4.08688103e+01],
#        [ 5.03455724e+01, -4.29319655e+01],
#        [ 5.20520413e+01, -4.50650516e+01],
#        [ 5.38163511e+01, -4.72704389e+01],
#        [ 5.56404625e+01, -4.95505781e+01],
#        [ 5.75264022e+01, -5.19080028e+01],
#        [ 5.94762662e+01, -5.43453327e+01],
#        [ 6.14922210e+01, -5.68652762e+01],
#        [ 6.35765068e+01, -5.94706335e+01],
#        [ 6.57314397e+01, -6.21642996e+01],
#        [ 6.79594143e+01, -6.49492679e+01],
#        [ 7.02629064e+01, -6.78286330e+01],
#        [ 7.26444756e+01, -7.08055944e+01],
#        [ 7.51067683e+01, -7.38834604e+01],
#        [ 7.76525207e+01, -7.70656509e+01],
#        [ 8.02845617e+01, -8.03557022e+01],
#        [ 8.30058161e+01, -8.37572701e+01],
#        [ 8.58193076e+01, -8.72741345e+01],
#        [ 8.87281628e+01, -9.09102035e+01],
#        [ 9.17356140e+01, -9.46695175e+01],
#        [ 9.48450030e+01, -9.85562538e+01],
#        [ 9.80597852e+01, -1.02574731e+02],
#        [ 1.01383533e+02, -1.06729416e+02],
#        [ 1.04819939e+02, -1.11024924e+02],
#        [ 1.08372823e+02, -1.15466028e+02],
#        [ 1.12046132e+02, -1.20057665e+02],
#        [ 1.15843948e+02, -1.24804935e+02],
#        [ 1.19770492e+02, -1.29713115e+02],
#        [ 1.23830126e+02, -1.34787658e+02],
#        [ 1.28027363e+02, -1.40034203e+02],
#        [ 1.32366865e+02, -1.45458581e+02],
#        [ 1.36853455e+02, -1.51066818e+02],
#        [ 1.41492118e+02, -1.56865147e+02],
#        [ 1.46288009e+02, -1.62860012e+02],
#        [ 1.51246458e+02, -1.69058073e+02],
#        [ 1.56372974e+02, -1.75466217e+02],
#        [ 1.61673254e+02, -1.82091567e+02],
#        [ 1.67153187e+02, -1.88941484e+02],
#        [ 1.72818863e+02, -1.96023579e+02],
#        [ 1.78676578e+02, -2.03345723e+02],
#        [ 1.84732841e+02, -2.10916051e+02],
#        [ 1.90994382e+02, -2.18742977e+02],
#        [ 1.97468158e+02, -2.26835197e+02],
#        [ 2.04161363e+02, -2.35201704e+02],
#        [ 2.11081436e+02, -2.43851795e+02],
#        [ 2.18236065e+02, -2.52795082e+02],
#        [ 2.25633202e+02, -2.62041502e+02],
#        [ 2.33281064e+02, -2.71601331e+02],
#        [ 2.41188153e+02, -2.81485191e+02],
#        [ 2.49363252e+02, -2.91704066e+02],
#        [ 2.57815448e+02, -3.02269310e+02],
#        [ 2.66554132e+02, -3.13192665e+02],
#        [ 2.75589015e+02, -3.24486268e+02],
#        [ 2.84930136e+02, -3.36162669e+02],
#        [ 2.94587875e+02, -3.48234844e+02],
#        [ 3.04572964e+02, -3.60716205e+02],
#        [ 3.14896500e+02, -3.73620624e+02],
#        [ 3.25569952e+02, -3.86962440e+02],
#        [ 3.36605183e+02, -4.00756478e+02],
#        [ 3.48014453e+02, -4.15018067e+02],
#        [ 3.59810443e+02, -4.29763054e+02],
#        [ 3.72006259e+02, -4.45007823e+02],
#        [ 3.84615453e+02, -4.60769316e+02],
#        [ 3.97652038e+02, -4.77065047e+02],
#        [ 4.11130498e+02, -4.93913123e+02],
#        [ 4.25065813e+02, -5.11332267e+02],
#        [ 4.39473467e+02, -5.29341834e+02],
#        [ 4.54369470e+02, -5.47961838e+02],
#        [ 4.69770375e+02, -5.67212969e+02],
#        [ 4.85693295e+02, -5.87116619e+02],
#        [ 5.02155925e+02, -6.07694906e+02],
#        [ 5.19176557e+02, -6.28970696e+02],
#        [ 5.36774105e+02, -6.50967631e+02],
#        [ 5.54968124e+02, -6.73710155e+02],
#        [ 5.73778832e+02, -6.97223540e+02],
#        [ 5.93227131e+02, -7.21533913e+02],
#        [ 6.13334632e+02, -7.46668289e+02],
#        [ 6.34123679e+02, -7.72654598e+02],
#        [ 6.55617373e+02, -7.99521716e+02],
#        [ 6.77839598e+02, -8.27299497e+02],
#        [ 7.00815048e+02, -8.56018810e+02],
#        [ 7.24569254e+02, -8.85711567e+02],
#        [ 7.49128611e+02, -9.16410763e+02],
#        [ 7.74520410e+02, -9.48150512e+02],
#        [ 8.00772867e+02, -9.80966084e+02],
#        [ 8.27915154e+02, -1.01489394e+03],
#        [ 8.55977433e+02, -1.04997179e+03],
#        [ 8.84990885e+02, -1.08623861e+03],
#        [ 9.14987751e+02, -1.12373469e+03],
#        [ 9.46001365e+02, -1.16250171e+03],
#        [ 9.78066189e+02, -1.20258274e+03],
#        [ 1.01121785e+03, -1.24402232e+03],
#        [ 1.04549320e+03, -1.28686650e+03],
#        [ 1.08093031e+03, -1.33116288e+03],
#        [ 1.11756856e+03, -1.37696070e+03],
#        [ 1.15544868e+03, -1.42431085e+03],
#        [ 1.19461274e+03, -1.47326593e+03],
#        [ 1.23510427e+03, -1.52388034e+03],
#        [ 1.27696827e+03, -1.57621034e+03],
#        [ 1.32025126e+03, -1.63031407e+03],
#        [ 1.36500133e+03, -1.68625166e+03],
#        [ 1.41126820e+03, -1.74408525e+03],
#        [ 1.45910330e+03, -1.80387912e+03],
#        [ 1.50855977e+03, -1.86569971e+03],
#        [ 1.55969257e+03, -1.92961572e+03],
#        [ 1.61255853e+03, -1.99569816e+03],
#        [ 1.66721638e+03, -2.06402048e+03],
#        [ 1.72372687e+03, -2.13465859e+03],
#        [ 1.78215279e+03, -2.20769099e+03],
#        [ 1.84255906e+03, -2.28319883e+03],
#        [ 1.90501281e+03, -2.36126601e+03],
#        [ 1.96958344e+03, -2.44197929e+03],
#        [ 2.03634269e+03, -2.52542836e+03],
#        [ 2.10536476e+03, -2.61170595e+03],
#        [ 2.17672633e+03, -2.70090792e+03],
#        [ 2.25050672e+03, -2.79313340e+03],
#        [ 2.32678790e+03, -2.88848488e+03],
#        [ 2.40565464e+03, -2.98706830e+03],
#        [ 2.48719458e+03, -3.08899322e+03],
#        [ 2.57149832e+03, -3.19437290e+03],
#        [ 2.65865955e+03, -3.30332443e+03],
#        [ 2.74877511e+03, -3.41596889e+03],
#        [ 2.84194516e+03, -3.53243145e+03],
#        [ 2.93827321e+03, -3.65284152e+03],
#        [ 3.03786632e+03, -3.77733290e+03],
#        [ 3.14083514e+03, -3.90604393e+03],
#        [ 3.24729410e+03, -4.03911763e+03],
#        [ 3.35736151e+03, -4.17670188e+03],
#        [ 3.47115966e+03, -4.31894957e+03],
#        [ 3.58881501e+03, -4.46601876e+03],
#        [ 3.71045830e+03, -4.61807287e+03],
#        [ 3.83622470e+03, -4.77528088e+03],
#        [ 3.96625398e+03, -4.93781747e+03],
#        [ 4.10069060e+03, -5.10586326e+03],
#        [ 4.23968398e+03, -5.27960497e+03],
#        [ 4.38338855e+03, -5.45923568e+03],
#        [ 4.53196400e+03, -5.64495500e+03],
#        [ 4.68557543e+03, -5.83696929e+03],
#        [ 4.84439355e+03, -6.03549193e+03],
#        [ 5.00859481e+03, -6.24074352e+03],
#        [ 5.17836170e+03, -6.45295213e+03],
#        [ 5.35388286e+03, -6.67235358e+03],
#        [ 5.53535333e+03, -6.89919166e+03],
#        [ 5.72297476e+03, -7.13371845e+03],
#        [ 5.91695564e+03, -7.37619455e+03],
#        [ 6.11751152e+03, -7.62688940e+03],
#        [ 6.32486527e+03, -7.88608159e+03],
#        [ 6.53924729e+03, -8.15405912e+03],
#        [ 6.76089582e+03, -8.43111978e+03],
#        [ 6.99005716e+03, -8.71757144e+03],
#        [ 7.22698594e+03, -9.01373242e+03],
#        [ 7.47194544e+03, -9.31993181e+03],
#        [ 7.72520788e+03, -9.63650985e+03],
#        [ 7.98705468e+03, -9.96381835e+03],
#        [ 8.25777681e+03, -1.03022210e+04],
#        [ 8.53767509e+03, -1.06520939e+04],
#        [ 8.82706056e+03, -1.10138257e+04],
#        [ 9.12625477e+03, -1.13878185e+04],
#        [ 9.43559022e+03, -1.17744878e+04],
#        [ 9.75541062e+03, -1.21742633e+04],
#        [ 1.00860714e+04, -1.25875892e+04],
#        [ 1.04279399e+04, -1.30149249e+04],
#        [ 1.07813961e+04, -1.34567451e+04],
#        [ 1.11468328e+04, -1.39135409e+04],
#        [ 1.15246559e+04, -1.43858199e+04]])

# %%
def plot_sol(sol):
    sim = get_sim_array(sol)
    P = list_plot(sim[:,0],legend_label='X')
    colors = ['blue','green']
    for i,var in enumerate(['S']):
        P += list_plot(sim[:,i+1],color=colors[i+1],legend_label=var)
   
    show(P, figsize=(16, 8))
plot_sol(T.solution)
# Out:
# Graphics object consisting of 2 graphics primitives

# %% [markdown]
# Note que, nesse caso, a concentração de substrato diminuirá rapidamente, já que é pelo menos 10 vezes menor que a concentração de células

# %%
T = ode_solver()
T.function = model
T.algorithm='rk8pd'
inits = [0.5, 5.0]
tspan = [0,100]
T.ode_solve(tspan, inits, num_points=200, params=[mu, D, Sf, Y, mumax, Ks])

# %%
def get_sim_array(sol):
    sim = np.array([y for t,y in sol])
    return sim
get_sim_array(T.solution)
# Out:
# array([[ 5.00000000e-01,  5.00000000e+00],
#        [ 5.16947557e-01,  1.06349373e+01],
#        [ 5.34469553e-01,  1.40436461e+01],
#        [ 5.52585459e-01,  1.61017721e+01],
#        [ 5.71315406e-01,  1.73404110e+01],
#        [ 5.90680206e-01,  1.80816779e+01],
#        [ 6.10701379e-01,  1.85209342e+01],
#        [ 6.31401172e-01,  1.87766611e+01],
#        [ 6.52802586e-01,  1.89207095e+01],
#        [ 6.74929404e-01,  1.89966464e+01],
#        [ 6.97806213e-01,  1.90308842e+01],
#        [ 7.21458433e-01,  1.90394296e+01],
#        [ 7.45912349e-01,  1.90319775e+01],
#        [ 7.71195133e-01,  1.90143941e+01],
#        [ 7.97334879e-01,  1.89902231e+01],
#        [ 8.24360635e-01,  1.89615986e+01],
#        [ 8.52302433e-01,  1.89297997e+01],
#        [ 8.81191320e-01,  1.88955860e+01],
#        [ 9.11059400e-01,  1.88594017e+01],
#        [ 9.41939862e-01,  1.88214992e+01],
#        [ 9.73867021e-01,  1.87820136e+01],
#        [ 1.00687635e+00,  1.87410087e+01],
#        [ 1.04100454e+00,  1.86985042e+01],
#        [ 1.07628951e+00,  1.86544925e+01],
#        [ 1.11277046e+00,  1.86089486e+01],
#        [ 1.15048795e+00,  1.85618365e+01],
#        [ 1.18948386e+00,  1.85131127e+01],
#        [ 1.22980156e+00,  1.84627283e+01],
#        [ 1.27148582e+00,  1.84106308e+01],
#        [ 1.31458298e+00,  1.83567640e+01],
#        [ 1.35914091e+00,  1.83010695e+01],
#        [ 1.40520915e+00,  1.82434859e+01],
#        [ 1.45283887e+00,  1.81839498e+01],
#        [ 1.50208301e+00,  1.81223953e+01],
#        [ 1.55299629e+00,  1.80587540e+01],
#        [ 1.60563527e+00,  1.79929555e+01],
#        [ 1.66005846e+00,  1.79249267e+01],
#        [ 1.71632633e+00,  1.78545920e+01],
#        [ 1.77450141e+00,  1.77818732e+01],
#        [ 1.83464833e+00,  1.77066895e+01],
#        [ 1.89683395e+00,  1.76289575e+01],
#        [ 1.96112735e+00,  1.75485908e+01],
#        [ 2.02759998e+00,  1.74655000e+01],
#        [ 2.09632572e+00,  1.73795928e+01],
#        [ 2.16738091e+00,  1.72907739e+01],
#        [ 2.24084454e+00,  1.71989443e+01],
#        [ 2.31679822e+00,  1.71040022e+01],
#        [ 2.39532635e+00,  1.70058421e+01],
#        [ 2.47651621e+00,  1.69043547e+01],
#        [ 2.56045801e+00,  1.67994275e+01],
#        [ 2.64724503e+00,  1.66909437e+01],
#        [ 2.73697370e+00,  1.65787829e+01],
#        [ 2.82974373e+00,  1.64628203e+01],
#        [ 2.92565821e+00,  1.63429272e+01],
#        [ 3.02482373e+00,  1.62189703e+01],
#        [ 3.12735048e+00,  1.60908119e+01],
#        [ 3.23335238e+00,  1.59583095e+01],
#        [ 3.34294722e+00,  1.58213160e+01],
#        [ 3.45625680e+00,  1.56796790e+01],
#        [ 3.57340701e+00,  1.55332412e+01],
#        [ 3.69452805e+00,  1.53818399e+01],
#        [ 3.81975450e+00,  1.52253069e+01],
#        [ 3.94922551e+00,  1.50634681e+01],
#        [ 4.08308496e+00,  1.48961438e+01],
#        [ 4.22148158e+00,  1.47231480e+01],
#        [ 4.36456918e+00,  1.45442885e+01],
#        [ 4.51250675e+00,  1.43593666e+01],
#        [ 4.66545868e+00,  1.41681767e+01],
#        [ 4.82359493e+00,  1.39705063e+01],
#        [ 4.98709123e+00,  1.37661360e+01],
#        [ 5.15612925e+00,  1.35548384e+01],
#        [ 5.33089684e+00,  1.33363790e+01],
#        [ 5.51158819e+00,  1.31105148e+01],
#        [ 5.69840410e+00,  1.28769949e+01],
#        [ 5.89155215e+00,  1.26355598e+01],
#        [ 6.09124698e+00,  1.23859413e+01],
#        [ 6.29771049e+00,  1.21278619e+01],
#        [ 6.51117210e+00,  1.18610349e+01],
#        [ 6.73186902e+00,  1.15851637e+01],
#        [ 6.96004648e+00,  1.12999419e+01],
#        [ 7.19595805e+00,  1.10050524e+01],
#        [ 7.43986586e+00,  1.07001677e+01],
#        [ 7.69204096e+00,  1.03849488e+01],
#        [ 7.95276356e+00,  1.00590455e+01],
#        [ 8.22232339e+00,  9.72209577e+00],
#        [ 8.50101997e+00,  9.37372504e+00],
#        [ 8.78916301e+00,  9.01354624e+00],
#        [ 9.08707268e+00,  8.64115914e+00],
#        [ 9.39508004e+00,  8.25614994e+00],
#        [ 9.71352735e+00,  7.85809081e+00],
#        [ 1.00427685e+01,  7.44653942e+00],
#        [ 1.03831692e+01,  7.02103845e+00],
#        [ 1.07351079e+01,  6.58111508e+00],
#        [ 1.10989756e+01,  6.12628045e+00],
#        [ 1.14751767e+01,  5.65602915e+00],
#        [ 1.18641291e+01,  5.16983863e+00],
#        [ 1.22662651e+01,  4.66716863e+00],
#        [ 1.26820315e+01,  4.14746057e+00],
#        [ 1.31118904e+01,  3.61013694e+00],
#        [ 1.35563195e+01,  3.05460067e+00],
#        [ 1.40158124e+01,  2.48023444e+00],
#        [ 1.44908800e+01,  1.88640000e+00],
#        [ 1.49820500e+01,  1.27243747e+00],
#        [ 1.54898683e+01,  6.37664613e-01],
#        [ 1.60148992e+01, -1.86239432e-02],
#        [ 1.65577260e+01, -6.97157474e-01],
#        [ 1.71189520e+01, -1.39868998e+00],
#        [ 1.76992008e+01, -2.12400100e+00],
#        [ 1.82991172e+01, -2.87389653e+00],
#        [ 1.89193679e+01, -3.64920985e+00],
#        [ 1.95606420e+01, -4.45080250e+00],
#        [ 2.02236522e+01, -5.27956523e+00],
#        [ 2.09091352e+01, -6.13641896e+00],
#        [ 2.16178527e+01, -7.02231585e+00],
#        [ 2.23505922e+01, -7.93824031e+00],
#        [ 2.31081681e+01, -8.88521013e+00],
#        [ 2.38914221e+01, -9.86427761e+00],
#        [ 2.47012246e+01, -1.08765307e+01],
#        [ 2.55384754e+01, -1.19230942e+01],
#        [ 2.64041049e+01, -1.30051311e+01],
#        [ 2.72990750e+01, -1.41238438e+01],
#        [ 2.82243803e+01, -1.52804753e+01],
#        [ 2.91810488e+01, -1.64763110e+01],
#        [ 3.01701438e+01, -1.77126797e+01],
#        [ 3.11927642e+01, -1.89909553e+01],
#        [ 3.22500465e+01, -2.03125582e+01],
#        [ 3.33431655e+01, -2.16789569e+01],
#        [ 3.44733359e+01, -2.30916699e+01],
#        [ 3.56418135e+01, -2.45522669e+01],
#        [ 3.68498968e+01, -2.60623711e+01],
#        [ 3.80989283e+01, -2.76236604e+01],
#        [ 3.93902958e+01, -2.92378697e+01],
#        [ 4.07254343e+01, -3.09067929e+01],
#        [ 4.21058276e+01, -3.26322844e+01],
#        [ 4.35330094e+01, -3.44162617e+01],
#        [ 4.50085657e+01, -3.62607071e+01],
#        [ 4.65341361e+01, -3.81676701e+01],
#        [ 4.81114159e+01, -4.01392699e+01],
#        [ 4.97421578e+01, -4.21776973e+01],
#        [ 5.14281739e+01, -4.42852174e+01],
#        [ 5.31713377e+01, -4.64641721e+01],
#        [ 5.49735862e+01, -4.87169828e+01],
#        [ 5.68369222e+01, -5.10461527e+01],
#        [ 5.87634161e+01, -5.34542701e+01],
#        [ 6.07552088e+01, -5.59440109e+01],
#        [ 6.28145135e+01, -5.85181418e+01],
#        [ 6.49436185e+01, -6.11795232e+01],
#        [ 6.71448898e+01, -6.39311123e+01],
#        [ 6.94207735e+01, -6.67759669e+01],
#        [ 7.17737985e+01, -6.97172481e+01],
#        [ 7.42065796e+01, -7.27582244e+01],
#        [ 7.67218200e+01, -7.59022750e+01],
#        [ 7.93223148e+01, -7.91528935e+01],
#        [ 8.20109536e+01, -8.25136921e+01],
#        [ 8.47907242e+01, -8.59884053e+01],
#        [ 8.76647155e+01, -8.95808943e+01],
#        [ 9.06361209e+01, -9.32951512e+01],
#        [ 9.37082425e+01, -9.71353032e+01],
#        [ 9.68844941e+01, -1.01105618e+02],
#        [ 1.00168405e+02, -1.05210506e+02],
#        [ 1.03563624e+02, -1.09454531e+02],
#        [ 1.07073925e+02, -1.13842407e+02],
#        [ 1.10703208e+02, -1.18379010e+02],
#        [ 1.14455506e+02, -1.23069382e+02],
#        [ 1.18334988e+02, -1.27918735e+02],
#        [ 1.22345966e+02, -1.32932458e+02],
#        [ 1.26492897e+02, -1.38116121e+02],
#        [ 1.30780388e+02, -1.43475485e+02],
#        [ 1.35213204e+02, -1.49016505e+02],
#        [ 1.39796271e+02, -1.54745338e+02],
#        [ 1.44534681e+02, -1.60668351e+02],
#        [ 1.49433700e+02, -1.66792126e+02],
#        [ 1.54498773e+02, -1.73123466e+02],
#        [ 1.59735526e+02, -1.79669408e+02],
#        [ 1.65149780e+02, -1.86437225e+02],
#        [ 1.70747550e+02, -1.93434438e+02],
#        [ 1.76535058e+02, -2.00668823e+02],
#        [ 1.82518734e+02, -2.08148417e+02],
#        [ 1.88705227e+02, -2.15881534e+02],
#        [ 1.95101412e+02, -2.23876765e+02],
#        [ 2.01714397e+02, -2.32142996e+02],
#        [ 2.08551529e+02, -2.40689411e+02],
#        [ 2.15620407e+02, -2.49525509e+02],
#        [ 2.22928885e+02, -2.58661106e+02],
#        [ 2.30485085e+02, -2.68106356e+02],
#        [ 2.38297403e+02, -2.77871754e+02],
#        [ 2.46374521e+02, -2.87968151e+02],
#        [ 2.54725413e+02, -2.98406766e+02],
#        [ 2.63359360e+02, -3.09199200e+02],
#        [ 2.72285955e+02, -3.20357444e+02],
#        [ 2.81515118e+02, -3.31893898e+02],
#        [ 2.91057105e+02, -3.43821382e+02],
#        [ 3.00922519e+02, -3.56153149e+02],
#        [ 3.11122322e+02, -3.68902902e+02],
#        [ 3.21667848e+02, -3.82084810e+02],
#        [ 3.32570817e+02, -3.95713521e+02],
#        [ 3.43843342e+02, -4.09804178e+02],
#        [ 3.55497951e+02, -4.24372439e+02],
#        [ 3.67547595e+02, -4.39434493e+02],
#        [ 3.80005662e+02, -4.55007078e+02],
#        [ 3.92885997e+02, -4.71107496e+02]])

# %%
def plot_sol(sol):
    sim = get_sim_array(sol)
    P = list_plot(sim[:,0],legend_label='X')
    colors = ['blue','green']
    for i,var in enumerate(['S']):
        P += list_plot(sim[:,i+1],color=colors[i+1],legend_label=var)
   
    show(P, figsize=(16, 8))
plot_sol(T.solution)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
T = ode_solver()
T.function = model
T.algorithm='rk8pd'
inits = [0.5, 5.0]
tspan = [0,75]
T.ode_solve(tspan, inits, num_points=200, params=[mu, D, Sf, Y, mumax, Ks])

# %%
def get_sim_array(sol):
    sim = np.array([y for t,y in sol])
    return sim
get_sim_array(T.solution)
# Out:
# array([[  0.5       ,   5.        ],
#        [  0.51265756,   9.47939467],
#        [  0.52563555,  12.55268637],
#        [  0.53894208,  14.65944319],
#        [  0.55258546,  16.10177212],
#        [  0.56657423,  17.08730457],
#        [  0.58091712,  17.75873975],
#        [  0.59562311,  18.21414961],
#        [  0.61070138,  18.52093417],
#        [  0.62616136,  18.72541285],
#        [  0.64201271,  18.85941652],
#        [  0.65826534,  18.94481809],
#        [  0.6749294 ,  18.99664642],
#        [  0.69201532,  19.02522637],
#        [  0.70953377,  19.03764971],
#        [  0.72749571,  19.03878602],
#        [  0.74591235,  19.0319775 ],
#        [  0.76479521,  19.01951645],
#        [  0.78415609,  19.00297349],
#        [  0.8040071 ,  18.98342309],
#        [  0.82436064,  18.96159862],
#        [  0.84522942,  18.93799887],
#        [  0.86662651,  18.91296127],
#        [  0.88856526,  18.88671224],
#        [  0.9110594 ,  18.85940173],
#        [  0.93412298,  18.83112701],
#        [  0.95777041,  18.801949  ],
#        [  0.98201649,  18.77190345],
#        [  1.00687635,  18.74100872],
#        [  1.03236555,  18.70927101],
#        [  1.05850001,  18.67668801],
#        [  1.08529606,  18.64325141],
#        [  1.11277046,  18.6089486 ],
#        [  1.14094038,  18.57376382],
#        [  1.16982343,  18.537679  ],
#        [  1.19943765,  18.50067427],
#        [  1.22980156,  18.46272835],
#        [  1.26093413,  18.42381879],
#        [  1.29285483,  18.38392215],
#        [  1.32558361,  18.3430141 ],
#        [  1.35914091,  18.30106946],
#        [  1.39354773,  18.25806231],
#        [  1.42882556,  18.21396597],
#        [  1.46499645,  18.16875301],
#        [  1.50208301,  18.12239525],
#        [  1.54010842,  18.0748638 ],
#        [  1.57909645,  18.02612897],
#        [  1.61907147,  17.97616034],
#        [  1.66005846,  17.9249267 ],
#        [  1.70208304,  17.87239605],
#        [  1.74517148,  17.81853555],
#        [  1.78935071,  17.76331155],
#        [  1.83464833,  17.70668953],
#        [  1.88109268,  17.64863412],
#        [  1.92871277,  17.58910902],
#        [  1.97753836,  17.52807703],
#        [  2.02759998,  17.46550001],
#        [  2.07892892,  17.40133884],
#        [  2.13155726,  17.33555342],
#        [  2.18551789,  17.26810264],
#        [  2.24084454,  17.19894433],
#        [  2.29757178,  17.12803527],
#        [  2.35573509,  17.05533113],
#        [  2.41537081,  16.98078649],
#        [  2.47651621,  16.90435473],
#        [  2.53920952,  16.8259881 ],
#        [  2.60348991,  16.74563761],
#        [  2.66939757,  16.66325303],
#        [  2.7369737 ,  16.57878288],
#        [  2.80626051,  16.49217436],
#        [  2.87730134,  16.40337333],
#        [  2.95014057,  16.31232429],
#        [  3.02482373,  16.21897033],
#        [  3.10139751,  16.12325311],
#        [  3.17990976,  16.0251128 ],
#        [  3.26040956,  15.92448805],
#        [  3.34294722,  15.82131597],
#        [  3.42757433,  15.71553208],
#        [  3.51434379,  15.60707026],
#        [  3.60330983,  15.49586272],
#        [  3.69452805,  15.38183994],
#        [  3.78805547,  15.26493066],
#        [  3.88395055,  15.14506181],
#        [  3.98227323,  15.02215846],
#        [  4.08308496,  14.8961438 ],
#        [  4.18644874,  14.76693907],
#        [  4.2924292 ,  14.6344635 ],
#        [  4.40109256,  14.4986343 ],
#        [  4.51250675,  14.35936656],
#        [  4.6267414 ,  14.21657325],
#        [  4.74386792,  14.0701651 ],
#        [  4.86395951,  13.92005062],
#        [  4.98709123,  13.76613597],
#        [  5.11334004,  13.60832495],
#        [  5.24278486,  13.44651892],
#        [  5.37550659,  13.28061676],
#        [  5.51158819,  13.11051476],
#        [  5.65111471,  12.93610661],
#        [  5.79417336,  12.7572833 ],
#        [  5.94085356,  12.57393305],
#        [  6.09124698,  12.38594127],
#        [  6.24544763,  12.19319046],
#        [  6.40355189,  11.99556014],
#        [  6.56565858,  11.79292678],
#        [  6.73186902,  11.58516373],
#        [  6.90228709,  11.37214113],
#        [  7.07701932,  11.15372585],
#        [  7.25617492,  10.92978135],
#        [  7.43986586,  10.70016767],
#        [  7.62820696,  10.4647413 ],
#        [  7.82131594,  10.22335507],
#        [  8.0193135 ,   9.97585813],
#        [  8.22232339,   9.72209577],
#        [  8.43047249,   9.46190938],
#        [  8.64389092,   9.19513635],
#        [  8.86271206,   8.92160992],
#        [  9.08707268,   8.64115914],
#        [  9.31711302,   8.35360872],
#        [  9.55297686,   8.05877892],
#        [  9.79481162,   7.75648547],
#        [ 10.04276846,   7.44653942],
#        [ 10.29700236,   7.12874706],
#        [ 10.55767221,   6.80290974],
#        [ 10.82494096,   6.46882381],
#        [ 11.09897564,   6.12628045],
#        [ 11.37994755,   5.77506557],
#        [ 11.66803229,   5.41495964],
#        [ 11.96340993,   5.04573758],
#        [ 12.2662651 ,   4.66716863],
#        [ 12.57678708,   4.27901615],
#        [ 12.89516996,   3.88103755],
#        [ 13.22161274,   3.47298407],
#        [ 13.55631946,   3.05460067],
#        [ 13.89949932,   2.62562585],
#        [ 14.25136682,   2.18579147],
#        [ 14.61214189,   1.73482264],
#        [ 14.98205002,   1.27243747],
#        [ 15.36132243,   0.79834697],
#        [ 15.75019615,   0.31225481],
#        [ 16.14891427,  -0.18614284],
#        [ 16.55772598,  -0.69715747],
#        [ 16.97688681,  -1.22110851],
#        [ 17.40665874,  -1.75832343],
#        [ 17.84731041,  -2.30913801],
#        [ 18.29911722,  -2.87389653],
#        [ 18.76236158,  -3.45295197],
#        [ 19.23733302,  -4.04666628],
#        [ 19.72432843,  -4.65541054],
#        [ 20.22365218,  -5.27956523],
#        [ 20.73561637,  -5.91952047],
#        [ 21.260541  ,  -6.57567625],
#        [ 21.79875416,  -7.2484427 ],
#        [ 22.35059225,  -7.93824031],
#        [ 22.91640018,  -8.64550023],
#        [ 23.49653162,  -9.37066452],
#        [ 24.09134915, -10.11418643],
#        [ 24.70122455, -10.87653069],
#        [ 25.32653903, -11.65817379],
#        [ 25.96768342, -12.45960427],
#        [ 26.62505845, -13.28132307],
#        [ 27.29907502, -14.12384377],
#        [ 27.99015439, -14.98769299],
#        [ 28.69872852, -15.87341065],
#        [ 29.42524029, -16.78155037],
#        [ 30.1701438 , -17.71267975],
#        [ 30.93390463, -18.66738078],
#        [ 31.71700015, -19.64625019],
#        [ 32.51991983, -20.64989979],
#        [ 33.34316552, -21.6789569 ],
#        [ 34.18725177, -22.73406472],
#        [ 35.05270617, -23.81588272],
#        [ 35.94006965, -24.92508707],
#        [ 36.84989685, -26.06237106],
#        [ 37.78275643, -27.22844554],
#        [ 38.73923146, -28.42403933],
#        [ 39.71991978, -29.64989972],
#        [ 40.72543433, -30.90679292],
#        [ 41.75640361, -32.19550451],
#        [ 42.813472  , -33.51684   ],
#        [ 43.8973002 , -34.87162526],
#        [ 45.00856565, -36.26070706],
#        [ 46.14796291, -37.68495364],
#        [ 47.31620416, -39.1452552 ],
#        [ 48.51401957, -40.64252446],
#        [ 49.74215782, -42.17769728],
#        [ 51.00138654, -43.75173318],
#        [ 52.29249279, -45.36561599],
#        [ 53.61628355, -47.02035443],
#        [ 54.97358623, -48.71698278],
#        [ 56.36524919, -50.45656148],
#        [ 57.79214226, -52.24017783],
#        [ 59.25515731, -54.06894664],
#        [ 60.75520876, -55.94401095],
#        [ 62.29323419, -57.86654274],
#        [ 63.87019492, -59.83774365],
#        [ 65.48707661, -61.85884576],
#        [ 67.14488984, -63.9311123 ],
#        [ 68.84467082, -66.05583853],
#        [ 70.58748196, -68.23435245],
#        [ 72.37441257, -70.46801572],
#        [ 74.20657955, -72.75822444]])

# %%
def plot_sol(sol):
    sim = get_sim_array(sol)
    P = list_plot(sim[:,0],legend_label='X')
    colors = ['blue','green']
    for i,var in enumerate(['S']):
        P += list_plot(sim[:,i+1],color=colors[i+1],legend_label=var)
   
    show(P, figsize=(16, 8))
plot_sol(T.solution)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
var('x s mu D Sf X S mumax Ks')

mu=mumax*S/(Ks + S)

X = function('X')(t)
S = function('S')(t)
de1 = diff(X,t) == mu*X - D*X
de2 = diff(S,t) == D*Sf - D*S -(mu*X/Y)
sol = desolve_system([de1,de2],[X,S],ics=[0,500,0], ivar=t)
show(sol)
# Out:
# [X(t) == 500*e^(-(D*Ks + D*S - S*mumax)*t/(Ks + S)),
#  S(t) == -(Sf - 625)*e^(-D*t) + Sf - 625*e^(-(D*Ks + D*S - S*mumax)*t/(Ks + S))]

# %%
# Atribuindo  valores para as taxas de conversão:
solX, solS = sol[0].rhs(), sol[1].rhs()
plot((solX(mumax=1.6, Ks=1.0, D=1.0, Y=0.8, Sf=20.0, mu=mumax*S/(Ks+S), X=0.5, S=5.0),solS(mumax=1.6, Ks=1.0, D=1.0, Y=0.8, Sf=20.0, mu=mumax*S/(Ks+S), X=0.5, S=5.0)),(t,0,30))
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
def ODEsys(t,y,params):
    mumax, Ks, D, Y, Sf = params
    X,S = y
    return[(mumax*S/(Ks+S))*X - D*X, #dX/dt
        D*Sf - D*S -((mumax*S/(Ks+S))*X/Y) # dS/dt
          ]

# %%
T=ode_solver()
T.algorithm="rk8pd"
T.function=ODEsys
T.ode_solve(y_0=[0.5,5.0],t_span=[0,50],params=[1.6, 1.0, 1.0, 0.8, 20.0],num_points=200)

# %%
T.solution[:10]
# Out:
# [(0, [0.500000000000000, 5.00000000000000]),
#  (0.25, [0.5508154106859479, 8.11621947999112]),
#  (0.5, [0.6156267429334993, 10.511588337964021]),
#  (0.75, [0.6926353176917815, 12.34393665723319]),
#  (1.0, [0.7821561250298863, 13.734037876873197]),
#  (1.25, [0.8852470473593016, 14.77493473593567]),
#  (1.5, [1.0033864743221768, 15.538270854963697]),
#  (1.75, [1.138378573332775, 16.079026346234016]),
#  (2.0, [1.2923291674844464, 16.439143844118284]),
#  (2.25, [1.4676488596408022, 16.65032507237235])]

# %%
x=list_plot([(i[0],i[1][0]) for i in T.solution],color='blue', pointsize=20, legend_label='X', alpha=.8)
s=list_plot([(i[0],i[1][1]) for i in T.solution],color='green', pointsize=20, legend_label='S', alpha=.8)
x.legend()
s.legend()
show(x+s)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
var('X S mumax Ks D Y Sf')
dxdt(X, S) = (mumax*S/(Ks+S))*X - D*X
dsdt(X, S) = D*Sf - D*S -((mumax*S/(Ks+S))*X/Y)
eqs = solve([dxdt, dsdt], [X, S])
show(html("<h4>Equilíbrios:</h4>"))
show(eqs)
# Out:
# <h4>Equilíbrios:</h4>
# [[X == 0, S == -Ks], [X == 0, S == Sf], [X == -(Sf*Y*mumax - (D*Ks + D*Sf)*Y)/(D - mumax), S == -D*Ks/(D - mumax)]]

# %% [markdown]
# mumax = 1.6
#
# Ks = 1.0
#
# D = 1.0
#
# Y = 0.8
#
# Sf = 20.0

# %%
M = matrix([[1.6, 1.0, 1.0, 0, 0],[1.6, 1.0, 1.0, 0.8, 20.0]])
show("M=",M) 
Y = matrix([[X],[S]])
show("Y=",Y)
M*Y
# Out:
# 'M=' [ 1.60000000000000  1.00000000000000  1.00000000000000 0.000000000000000 0.000000000000000]
# [ 1.60000000000000  1.00000000000000  1.00000000000000 0.800000000000000  20.0000000000000]
# 'Y=' [X]
# [S]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-73-f562298eaf04> in <module>
#       3 Y = matrix([[X],[S]])
#       4 show("Y=",Y)
# ----> 5 M*Y
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/structure/element.pyx in sage.structure.element.Matrix.__mul__ (build/cythonized/sage/structure/element.c:23925)()
#    3813
#    3814         if BOTH_ARE_ELEMENT(cl):
# -> 3815             return coercion_model.bin_op(left, right, mul)
#    3816
#    3817         cdef long value
#
# ~/Documents/FGV/sage-9.2-Ubuntu_20.04-x86_64/SageMath/local/lib/python3.8/site-packages/sage/structure/coerce.pyx in sage.structure.coerce.CoercionModel.bin_op (build/cythonized/sage/structure/coerce.c:11304)()
#    1246         # We should really include the underlying error.
#    1247         # This causes so much headache.
# -> 1248         raise bin_op_exception(op, x, y)
#    1249
#    1250     cpdef canonical_coercion(self, x, y):
#
# TypeError: unsupported operand parent(s) for *: 'Full MatrixSpace of 2 by 5 dense matrices over Real Field with 53 bits of precision' and 'Full MatrixSpace of 2 by 1 dense matrices over Symbolic Ring'
