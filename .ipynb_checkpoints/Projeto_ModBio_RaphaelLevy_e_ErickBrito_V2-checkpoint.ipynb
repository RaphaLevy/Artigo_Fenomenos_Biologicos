# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint

# %% [markdown]
# Os parâmetros iniciais e modelagem foram retiradas do artigo 'Analytical solution for a hybrid Logistic-Monod cell growth model in batch and continuous stirred tank reactor culture. Peng Xu, 2019. (https://doi.org/10.1002/bit.27230)

# %%
# valores de parâmetros

mumax = 1.6   # 1/hora #taxa máxima de crescimento específica
Ks = 1.00     # g/litro #constante de saturação
Yxs = 0.8     # g/g #alto coeficiente de rendimento de biomassa (massa celular/massa do substrato limitante)
Sf = 20.0     # g/litro #concentração do substrato de alimentação (feeding stream)
D = 1.00      # 1/hora #taxa de diluição = F(t)/V

# definição de parâmetros

def mu(S):
    return mumax*S/(Ks + S)

def Rg(X,S):
    return mu(S)*X

# equações diferenciais

def xdif(x,t):
    X,S = x
    dX = Rg(X,S)-D*X
    dS = D*(Sf - S) - Rg(X,S)/Yxs
    return [dX,dS]

def xprim(x,u):
    X,S = x
    X = Yxs*(Sf-(Ks*D)/(mumax-D))
    S = Ks*D/(mumax-D)
    return [X,S]

# %%
IC = [0.05, 10.0]

t = np.linspace(0,50)
sol = odeint(xdif,IC,t)
X,S = sol.transpose()

plt.plot(t,X)
plt.plot(t,S)

plt.xlabel('Time [hr]')
plt.ylabel('Concentration [g/liter]')
plt.legend(['Cell Conc.',
            'Substrate Conc.'])

# %%
IC = [14.6666666666667, 1.66666666666667]

t = np.linspace(0,50)
sol = odeint(xdif,IC,t)
X,S = sol.transpose()

plt.plot(t,X)
plt.plot(t,S)

plt.xlabel('Time [hr]')
plt.ylabel('Concentration [g/liter]')
plt.legend(['Cell Conc.',
            'Substrate Conc.'])

# %%
u = np.linspace(0,50)
solprim = odeint(xprim,IC,u)
X,S = solprim.transpose()

plt.plot(u,X)
plt.plot(u,S)

plt.xlabel('Time [hr]')
plt.ylabel('Concentration [g/liter]')
plt.legend(['Cell Conc.',
            'Substrate Conc.'])

# %%
# valores de parâmetros

mumax = 1.6   # 1/hora #taxa máxima de crescimento específica
Ks = 1.00     # g/litro #constante de saturação
Yxs2 = 0.3    # g/g #baixo coeficiente de rendimento de biomassa (massa celular/massa do substrato limitante)
Sf = 20.0     # g/litro #concentração do substrato de alimentação (feeding stream)
D = 1.00      # 1/hora #taxa de diluição = F(t)/V

# definição de parâmetros

def mu(S):
    return mumax*S/(Ks + S)

def Rg(X,S):
    return mu(S)*X

# equações diferenciais

def xdif2(x,t):
    X,S = x
    dX = Rg(X,S)-D*X
    dS = D*(Sf - S) - Rg(X,S)/Yxs2
    return [dX,dS]

def xprim2(x,u):
    X,S = x
    X = Yxs2*(Sf-(Ks*D)/(mumax-D))
    S = Ks*D/(mumax-D)
    return [X,S]

# %%
IC = [0.05, 10.0]

t = np.linspace(0,50)
sol2 = odeint(xdif2,IC,t)
X,S = sol2.transpose()

plt.plot(t,X)
plt.plot(t,S)

plt.xlabel('Time [hr]')
plt.ylabel('Concentration [g/liter]')
plt.legend(['Cell Conc.',
            'Substrate Conc.'])

# %%
u = np.linspace(0,50)
solprim2 = odeint(xprim2,IC,u)
X,S = solprim2.transpose()

plt.plot(u,X)
plt.plot(u,S)

plt.xlabel('Time [hr]')
plt.ylabel('Concentration [g/liter]')
plt.legend(['Cell Conc.',
            'Substrate Conc.'])

# %%
# Alterando os valores de parâmetros

mumax_new = 0.2   
Ks_new = 1.00     
Yxs_new = 0.5     
Sf_new = 10.0     
D_new = 1.00      

# definição de parâmetros

def mu_new(S):
    return mumax_new*S/(Ks_new + S)

def Rg_new(X,S):
    return mu_new(S)*X

# equações diferenciais

def xdif_new(x,t):
    X,S = x
    dX = Rg_new(X,S)-D_new*X
    dS = D_new*(Sf_new - S) - Rg_new(X,S)/Yxs_new
    return [dX,dS]

def xprim_new(x,u):
    X,S = x
    X = Yxs_new*(Sf_new-(Ks_new*D_new)/(mumax_new-D_new))
    S = Ks_new*D_new/(mumax_new-D_new)
    return [X,S]

# %%
IC = [0.05, 10.0]

t = np.linspace(0,50)
sol_new = odeint(xdif_new,IC,t)
X,S = sol_new.transpose()

plt.plot(t,X)
plt.plot(t,S)

plt.xlabel('Time [hr]')
plt.ylabel('Concentration [g/liter]')
plt.legend(['Cell Conc.',
            'Substrate Conc.'])

# %%
# Alterando os valores de parâmetros

mumax_new2 = 1.0   
Ks_new2 = 4.00     
Yxs_new2 = 0.5     
Sf_new2 = 25.0     
D_new2 = 2.00      

# definição de parâmetros

def mu_new2(S):
    return mumax_new2*S/(Ks_new2 + S)

def Rg_new2(X,S):
    return mu_new2(S)*X

# equações diferenciais

def xdif_new2(x,t):
    X,S = x
    dX = Rg_new2(X,S)-D_new2*X
    dS = D_new2*(Sf_new2 - S) - Rg_new2(X,S)/Yxs_new2
    return [dX,dS]

def xprim_new2(x,u):
    X,S = x
    X = Yxs_new2*(Sf_new2-(Ks_new2*D_new2)/(mumax_new2-D_new2))
    S = Ks_new2*D_new2/(mumax_new2-D_new2)
    return [X,S]

# %%
IC = [0.05, 10.0]

t = np.linspace(0,50)
sol_new2 = odeint(xdif_new2,IC,t)
X,S = sol_new2.transpose()

plt.plot(t,X)
plt.plot(t,S)

plt.xlabel('Time [hr]')
plt.ylabel('Concentration [g/liter]')
plt.legend(['Cell Conc.',
            'Substrate Conc.'])

# %%
# Alterando os valores de parâmetros

mumax_new3 = 1.0   
Ks_new3 = 1.00     
Yxs_new3 = 0.8    
Sf_new3 = 20.0     
D_new3 = 1.00      

# definição de parâmetros

def mu_new3(S):
    return mumax_new3*S/(Ks_new3 + S)

def Rg_new3(X,S):
    return mu_new3(S)*X

# equações diferenciais

def xdif_new3(x,t):
    X,S = x
    dX = Rg_new3(X,S)-D_new3*X
    dS = D_new3*(Sf_new3 - S) - Rg_new3(X,S)/Yxs_new3
    return [dX,dS]

def xprim_new3(x,u):
    X,S = x
    X = Yxs_new3*(Sf_new3-(Ks_new3*D_new3)/(mumax_new3-D_new3))
    S = Ks_new3*D_new3/(mumax_new3-D_new3)
    return [X,S]

# %%
IC = [0.05, 10.0]

t = np.linspace(0,50)
sol_new3 = odeint(xdif_new3,IC,t)
X,S = sol_new3.transpose()

plt.plot(t,X)
plt.plot(t,S)

plt.xlabel('Time [hr]')
plt.ylabel('Concentration [g/liter]')
plt.legend(['Cell Conc.',
            'Substrate Conc.'])

# %%
# Alterando os valores de parâmetros

mumax_new4 = 2.0   
Ks_new4 = 1.00     
Yxs_new4 = 0.8    
Sf_new4 = 20.0     
D_new4 = 1.00      

# definição de parâmetros

def mu_new4(S):
    return mumax_new4*S/(Ks_new4 + S)

def Rg_new4(X,S):
    return mu_new4(S)*X

# equações diferenciais

def xdif_new4(x,t):
    X,S = x
    dX = Rg_new4(X,S)-D_new4*X
    dS = D_new4*(Sf_new4 - S) - Rg_new4(X,S)/Yxs_new4
    return [dX,dS]

def xprim_new4(x,u):
    X,S = x
    X = Yxs_new4*(Sf_new4-(Ks_new4*D_new4)/(mumax_new4-D_new4))
    S = Ks_new4*D_new4/(mumax_new4-D_new4)
    return [X,S]

# %%
IC = [0.05, 10.0]

t = np.linspace(0,50)
sol_new4 = odeint(xdif_new4,IC,t)
X,S = sol_new4.transpose()

plt.plot(t,X)
plt.plot(t,S)

plt.xlabel('Time [hr]')
plt.ylabel('Concentration [g/liter]')
plt.legend(['Cell Conc.',
            'Substrate Conc.'])

# %%
# Alterando os valores de parâmetros

mumax_new5 = 2.0   
Ks_new5 = 1.50     
Yxs_new5 = 0.8    
Sf_new5 = 20.0     
D_new5 = 1.00      

# definição de parâmetros

def mu_new5(S):
    return mumax_new5*S/(Ks_new5 + S)

def Rg_new5(X,S):
    return mu_new5(S)*X

# equações diferenciais

def xdif_new5(x,t):
    X,S = x
    dX = Rg_new5(X,S)-D_new5*X
    dS = D_new5*(Sf_new5 - S) - Rg_new5(X,S)/Yxs_new5
    return [dX,dS]

def xprim_new5(x,u):
    X,S = x
    X = Yxs_new5*(Sf_new5-(Ks_new5*D_new5)/(mumax_new5-D_new5))
    S = Ks_new5*D_new5/(mumax_new5-D_new5)
    return [X,S]

# %%
IC = [0.05, 10.0]

t = np.linspace(0,50)
sol_new5 = odeint(xdif_new5,IC,t)
X,S = sol_new5.transpose()

plt.plot(t,X)
plt.plot(t,S)

plt.xlabel('Time [hr]')
plt.ylabel('Concentration [g/liter]')
plt.legend(['Cell Conc.',
            'Substrate Conc.'])

# %% [markdown]
# Os parâmetros a seguir vieram do artigo 'Analyses of Various Control Schemes for Continuous Bioreactors', Pramod Agrawal and Henry C. Lim. (https://link.springer.com/chapter/10.1007/BFb0006380)

# %%
# valores de parâmetros

mumax = 0.4   # 1/hora #taxa máxima de crescimento específica
Ks = 0.05     # g/litro #constante de saturação
Yxs = 0.4     # g/g #alto coeficiente de rendimento de biomassa (massa celular/massa do substrato limitante)
Sf = 1.0     # g/litro #concentração do substrato de alimentação (feeding stream)
D = 0.381      # 1/hora #taxa de diluição = F(t)/V (OBS: D =< mumax*Sf/(Ks + Sf))

# definição de parâmetros

def mu(S):
    return mumax*S/(Ks + S)

def Rg(X,S):
    return mu(S)*X

# equações diferenciais

def xdif(x,t):
    X,S = x
    dX = Rg(X,S)-D*X
    dS = D*(Sf - S) - Rg(X,S)/Yxs
    return [dX,dS]

def xprim(x,u):
    X,S = x
    X = Yxs*(Sf-(Ks*D)/(mumax-D))
    S = Ks*D/(mumax-D)
    return [X,S]

# %%
IC = [0.05, 10.0]

t = np.linspace(0,50)
sol = odeint(xdif,IC,t)
X,S = sol.transpose()

plt.plot(t,X)
plt.plot(t,S)

plt.xlabel('Time [hr]')
plt.ylabel('Concentration [g/liter]')
plt.legend(['Cell Conc.',
            'Substrate Conc.'])

# %%
IC = [1.00, 1.00]

t = np.linspace(0,50)
sol = odeint(xdif,IC,t)
X,S = sol.transpose()

plt.plot(t,X)
plt.plot(t,S)

plt.xlabel('Time [hr]')
plt.ylabel('Concentration [g/liter]')
plt.legend(['Cell Conc.',
            'Substrate Conc.'])

# %%
IC = [0.5, 5.0]

t = np.linspace(0,50)
sol = odeint(xdif,IC,t)
X,S = sol.transpose()

plt.plot(t,X)
plt.plot(t,S)

plt.xlabel('Time [hr]')
plt.ylabel('Concentration [g/liter]')
plt.legend(['Cell Conc.',
            'Substrate Conc.'])
